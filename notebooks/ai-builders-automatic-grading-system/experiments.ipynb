# %% [markdown]
# #### Evaluating the accuracy on question reviews:

# %%
import json
from agent.state import OverallState
from agent.graphs import execute_graph

from IPython.display import Image, display
from langchain_core.runnables.graph import MermaidDrawMethod

#LOAD Benchmark:
def load_json_file(filename):
    import json
    with open(filename, 'r') as json_file:
        return json.load(json_file)

def read_text_file(filename):
    with open(filename, 'r') as file:
        return file.read()

benchmark_lesson_1 = load_json_file('data/evals/open_questions_lesson_1_input.json')
lesson_1_doc = read_text_file('data/lesson1.txt')

# %%
sample_case = benchmark_lesson_1["student_1"]
sample_case_input = {"open_questions": sample_case}

#Attaching all the concepts evaluated
total_concepts_eval = []
for elem in benchmark_lesson_1["student_1"]:
    total_concepts_eval += elem['concepts_evaluated']
unique_list_of_concepts = list(set(total_concepts_eval))

# %%
sample_case
# Out:
# [{'id': 0,
#   'question': 'What is the role of a prototype program in problem solving?',
#   'student_answer': 'High risk problems are address in the prototype program to make sure that the program is feasible.  A prototype may also be used to show a company that the software can be possibly programmed.',
#   'concepts_evaluated': ['problemsolving', 'prototyping']},
#  {'id': 29,
#   'question': 'What stages in the software life cycle are influenced by the testing stage?',
#   'student_answer': 'Refining and possibly the design if the testing phase reveals problems in the design. Production can be affected if the program is unworkable in its current form which will lead to a later production time than originally estimated. Also affects coding because after testing you may need to rewrite the code for the program to remove errors.',
#   'concepts_evaluated': ['sdlc', 'testing_phase']},
#  {'id': 58,
#   'question': 'What are the main advantages associated with object-oriented programming?',
#   'student_answer': 'Modularability, the ability to reuse parts of the program later in another program sometimes with completely different goals for the program. Also it makes it easier to debug code by dividing up the code into classes that each do a specific job and when the program fails at one job you only have one class to debug. Good for security purposes because it allows you to let someone use a program which sorts lists without having to give them access to the source code. ALso allows you to use inheritance and polymorphism.',
#   'concepts_evaluated': ['oop', 'inheritance', 'polymorphism', 'reusability']},
#  {'id': 87,
#   'question': 'Where do C++ programs begin to execute?',
#   'student_answer': 'At function ‘int main ()’',
#   'concepts_evaluated': ['c++_program_structure', 'int_main()']},
#  {'id': 116,
#   'question': 'What is a variable?',
#   'student_answer': 'Variable can be a integer or a string in a program.',
#   'concepts_evaluated': ['variables']},
#  {'id': 145,
#   'question': 'Where are variables declared in a C++ program?',
#   'student_answer': 'They can be declared right before they are used, but it is a good practice to declare them at the beginning of the program and label what they are food.',
#   'concepts_evaluated': ['c++_program_structure', 'variables']},
#  {'id': 174,
#   'question': 'What is the main difference between a while and a do...while statement?',
#   'student_answer': '"The “do” statement first evaluates the condition and then executes the lines of code in the statement 0 or more times. \tThe “do while” statement executes the lines of code and then it evaluates the condition. "',
#   'concepts_evaluated': ['control_flow', 'loops']}]

# %%
from agent.graphs import one_shot_graph
#TEST:
sample_state = OverallState(
    user_input = {"open_questions": sample_case},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    messages=[]
)

#Test OneShot:
graph = one_shot_graph()
display(Image(graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.API,)))

r = execute_graph(sample_state, graph)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      13 #Test OneShot:
#      14 graph = one_shot_graph()
# ---> 16 r = execute_graph(sample_state, graph)
#
# Cell In[7], line 11, in execute_graph(exec_state, graph)
#       4 unique_id = uuid.uuid4()
#       6 config = {
#       7         "configurable": { "thread_id": unique_id, "run_name": "AIBuildersDemo"},
#       8         "recursion_limit": 10
#       9         }
# ---> 11 for chunk in graph.stream(exec_state , config, stream_mode="values"):
#      12     try:
#      13         chunk["messages"][-1].pretty_print()
#
# File ~/miniconda3/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1307, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1296     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1297     # computation proceeds in steps, while there are channel updates
#    1298     # channel updates from step N are only visible in step N+1
#    1299     # channels are guaranteed to be immutable for the duration of the step,
#    1300     # with channel updates applied only at the transition between steps
#    1301     while loop.tick(
#    1302         input_keys=self.input_channels,
#    1303         interrupt_before=interrupt_before_,
#    1304         interrupt_after=interrupt_after_,
#    1305         manager=run_manager,
#    1306     ):
# -> 1307         for _ in runner.tick(
#    1308             loop.tasks.values(),
#    1309             timeout=self.step_timeout,
#    1310             retry_policy=self.retry_policy,
#    1311             get_waiter=get_waiter,
#    1312         ):
#    1313             # emit output
#    1314             yield from output()
#    1315 # emit output
#
# File ~/miniconda3/lib/python3.12/site-packages/langgraph/pregel/runner.py:56, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#      54 t = tasks[0]
#      55 try:
# ---> 56     run_with_retry(t, retry_policy)
#      57     self.commit(t, None)
#      58 except Exception as exc:
#
# File ~/miniconda3/lib/python3.12/site-packages/langgraph/pregel/retry.py:29, in run_with_retry(task, retry_policy)
#      27 task.writes.clear()
#      28 # run the task
# ---> 29 task.proc.invoke(task.input, config)
#      30 # if successful, end
#      31 break
#
# File ~/miniconda3/lib/python3.12/site-packages/langgraph/utils/runnable.py:410, in RunnableSeq.invoke(self, input, config, **kwargs)
#     408 context.run(_set_config_context, config)
#     409 if i == 0:
# --> 410     input = context.run(step.invoke, input, config, **kwargs)
#     411 else:
#     412     input = context.run(step.invoke, input, config)
#
# File ~/miniconda3/lib/python3.12/site-packages/langgraph/utils/runnable.py:184, in RunnableCallable.invoke(self, input, config, **kwargs)
#     182 else:
#     183     context.run(_set_config_context, config)
# --> 184     ret = context.run(self.func, input, **kwargs)
#     185 if isinstance(ret, Runnable) and self.recurse:
#     186     return ret.invoke(input, config)
#
# File ~/Desktop/Code_and_Projects/ai-notebooks/notebooks/ai-builders-automatic-grading-system/agent/nodes.py:52, in one_shot_call_evaluator(state)
#      40 model = ChatOpenAI(model="gpt-4o-mini", api_key=os.environ.get('OPENAI_API_KEY'))
#      42 messages = [
#      43     SystemMessage(content=EVALUATOR_SYSTEM_PROMPT_ONE_SHOT.format(
#      44         blooms_state=state['blooms_state'],
#    (...)
#      49         ))
#      50 ]
# ---> 52 llm_response = model.invoke(messages + state['messages'])
#      53 return {'messages': llm_response}
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:688, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     686     generation_info = {"headers": dict(raw_response.headers)}
#     687 else:
# --> 688     response = self.client.create(**payload)
#     689 return self._create_chat_result(response, generation_info)
#
# File ~/miniconda3/lib/python3.12/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/openai/resources/chat/completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File ~/miniconda3/lib/python3.12/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/lib/python3.12/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File ~/miniconda3/lib/python3.12/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/miniconda3/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/lib/python3.12/ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File ~/miniconda3/lib/python3.12/ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
#Test Basic Rag Call:
from agent.graphs import basic_rag_graph
sample_state = OverallState(
    user_input = {"open_questions": sample_case},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    messages=[]
)

graph = basic_rag_graph()
display(Image(graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.API,)))

r = execute_graph(sample_state, graph)
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_TvQBUE3CCi3uZszPeDCCAsdQ)
#  Call ID: call_TvQBUE3CCi3uZszPeDCCAsdQ
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_KreibVqzFT7JWUBix44cDgHn)
#  Call ID: call_KreibVqzFT7JWUBix44cDgHn
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_iOrIBsXVwMJHl79iWqiRlvvN)
#  Call ID: call_iOrIBsXVwMJHl79iWqiRlvvN
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_Asn0x2YeFBBjM7qWWUoUItN2)
#  Call ID: call_Asn0x2YeFBBjM7qWWUoUItN2
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_lY0xb5eqjdqXHal2qvpmJ09z)
#  Call ID: call_lY0xb5eqjdqXHal2qvpmJ09z
#   Args:
#     question: What is a variable?
#   query_lesson (call_DwyFYrRzeU65lLvwRh4qqRrk)
#  Call ID: call_DwyFYrRzeU65lLvwRh4qqRrk
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_phweLB9A9cfiG1NCTTCLA5tu)
#  Call ID: call_phweLB9A9cfiG1NCTTCLA5tu
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `int main()` function. This is the entry point of the program, where execution starts and the statements inside `main()` are carried out in order.
# The answer: The main difference between a while statement and a do...while statement in C++ lies in when the condition for the loop is evaluated:
#
# - **while loop**: The condition is checked at the beginning of the loop. If the condition evaluates to false before the loop body executes, the body will not run at all. For example:
#
#   ```cpp
#   while (condition) {
#       // loop body
#   }
#   ```
#
# - **do...while loop**: The loop body is executed at least once before the condition is checked at the end of the loop. This means that even if the condition is false, the body will run one time. For example:
#
#   ```cpp
#   do {
#       // loop body
#   } while (condition);
#   ```
#
# In summary, a while loop may not execute its body if the condition is false initially, while a do...while loop guarantees that its body executes at least once regardless of the condition.
# The answer: A variable is a storage location in a program that holds data, allowing you to store and manipulate information throughout the execution of the code. Each variable has a specific data type (such as integer, floating-point number, or string) that defines the kind of data it can hold. For instance, an integer variable can keep track of counts, while a string variable can store text. Choosing meaningful names for variables makes the code easier to read and maintain, and they are essential building blocks for organizing and managing data in your program.
# The answer: Object-oriented programming (OOP) offers several key advantages:
#
# 1. **Encapsulation**: OOP allows data and functions that operate on the data to be bundled together in classes. This encapsulation helps protect the integrity of the data and reduces complexity by hiding implementation details.
#
# 2. **Reusability**: Classes can be reused across different programs or projects. Once a class is created, it can be used as a blueprint to create multiple objects, saving time and effort in code development.
#
# 3. **Inheritance**: OOP supports inheritance, allowing new classes to derive properties and behaviors from existing classes. This promotes code reuse and establishes a natural hierarchy, making it easier to manage and extend code.
#
# 4. **Polymorphism**: OOP allows for polymorphism, enabling functions to operate on objects of different classes through a common interface. This flexibility enhances code extensibility and maintainability.
#
# 5. **Better Organization**: By structuring code into classes and objects, OOP helps organize complex systems into manageable pieces, making it easier for programmers to understand and maintain the code.
#
# 6. **Improved Collaboration**: OOP facilitates collaboration among developers. Multiple programmers can work on different classes and objects independently, which streamlines the development process.
#
# These advantages make OOP a powerful paradigm for building scalable and maintainable software systems.

# %%
#Test One Shot with reflection:
from agent.graphs import one_shot_with_reflection_graph

sample_state = OverallState(
    user_input = {"open_questions": sample_case},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    reflection_steps=0, #add it for reflection
    messages=[]
)

graph = one_shot_with_reflection_graph()
display(Image(graph.get_graph().draw_mermaid_png(draw_method=MermaidDrawMethod.API,)))
r = execute_graph(sample_state, graph)
# Out:
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer correctly identifies the role of prototypes in addressing high-risk problems and demonstrating feasibility, but lacks detail on how prototypes are developed and their iterative nature.",
#       "cited_paragraph": "A prototype program serves as a preliminary model to test concepts and feasibility, allowing for early detection of potential issues in problem-solving before full-scale development."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The answer provides a thorough understanding of how the testing stage influences refining, design, production, and coding phases, demonstrating a nuanced comprehension of the software development life cycle.",
#       "cited_paragraph": "The testing phase in the software life cycle is critical as it can lead to adjustments in design, refinement of features, and necessary code rewrites, ensuring the software meets its requirements before production."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The answer articulates several key advantages of object-oriented programming, such as modularity, reusability, ease of debugging, security, inheritance, and polymorphism, demonstrating a comprehensive understanding.",
#       "cited_paragraph": "Object-oriented programming offers several advantages, including modularity for easier debugging, reusability of code components, enhanced security through encapsulation, and the benefits of inheritance and polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer is correct and succinct, accurately stating that C++ programs begin execution at the 'int main()' function, which reflects a solid understanding of program structure.",
#       "cited_paragraph": "In C++, execution of a program begins at the 'int main()' function, which serves as the entry point for the program."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The answer gives a partial definition of a variable, identifying it as an integer or string, but lacks depth in explaining what variables are, their purpose in programming, and types beyond just these examples.",
#       "cited_paragraph": "A variable is a symbolic name associated with a value and can hold different data types, such as integers or strings, allowing for dynamic data manipulation within a program."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The answer indicates that variables can be declared before use and highlights good practice but could elaborate more on the scope and types of declarations within C++.",
#       "cited_paragraph": "In C++, variables can be declared at any point before their first use, though it is a common practice to declare them at the beginning of a program for clarity and maintainability."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "B",
#       "reason": "The answer correctly identifies the execution and evaluation order of 'while' and 'do...while' statements but could improve by explaining the implications of these differences on control flow.",
#       "cited_paragraph": "The main difference between 'while' and 'do...while' statements lies in their execution order; 'do...while' guarantees at least one execution of the loop body, while 'while' might not execute at all if the condition is false initially."
#     }
#   ]
# }
# ```
# call_reflection
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer correctly identifies the role of prototypes in addressing high-risk problems and demonstrating feasibility, but lacks detail on how prototypes are developed and their iterative nature.",
#       "cited_paragraph": "A prototype program serves as a preliminary model to test concepts and feasibility, allowing for early detection of potential issues in problem-solving before full-scale development."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The answer provides a thorough understanding of how the testing stage influences refining, design, production, and coding phases, demonstrating a nuanced comprehension of the software development life cycle.",
#       "cited_paragraph": "The testing phase in the software life cycle is critical as it can lead to adjustments in design, refinement of features, and necessary code rewrites, ensuring the software meets its requirements before production."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The answer articulates several key advantages of object-oriented programming, such as modularity, reusability, ease of debugging, security, inheritance, and polymorphism, demonstrating a comprehensive understanding.",
#       "cited_paragraph": "Object-oriented programming offers several advantages, including modularity for easier debugging, reusability of code components, enhanced security through encapsulation, and the benefits of inheritance and polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer is correct and succinct, accurately stating that C++ programs begin execution at the 'int main()' function, which reflects a solid understanding of program structure.",
#       "cited_paragraph": "In C++, execution of a program begins at the 'int main()' function, which serves as the entry point for the program."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The answer gives a partial definition of a variable, identifying it as an integer or string, but lacks depth in explaining what variables are, their purpose in programming, and types beyond just these examples.",
#       "cited_paragraph": "A variable is a symbolic name associated with a value and can hold different data types, such as integers or strings, allowing for dynamic data manipulation within a program."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The answer indicates that variables can be declared before use and highlights good practice but could elaborate more on the scope and types of declarations within C++.",
#       "cited_paragraph": "In C++, variables can be declared at any point before their first use, though it is a common practice to declare them at the beginning of a program for clarity and maintainability."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "B",
#       "reason": "The answer correctly identifies the execution and evaluation order of 'while' and 'do...while' statements but could improve by explaining the implications of these differences on control flow.",
#       "cited_paragraph": "The main difference between 'while' and 'do...while' statements lies in their execution order; 'do...while' guarantees at least one execution of the loop body, while 'while' might not execute at all if the condition is false initially."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# The evaluation provided appears to be mostly coherent and accurate, but there are some areas where the understanding of the evaluator can be further scrutinized.
#
# 1. **Prototype Program Evaluation (Score: B)**
#    - The reason provided mentions a lack of detail on how prototypes are developed and their iterative nature. It could be argued that the evaluation could be more nuanced by recognizing that while the initial answer did lack detail, it still conveyed a fundamental understanding of the role of prototypes. Thus, a score of A may be more appropriate.
#
# 2. **Variable Evaluation (Score: C)**
#    - The evaluator states that the answer gives a partial definition and lacks depth. However, the cited paragraph does mention that a variable is a symbolic name associated with a value and can hold different data types. While it could certainly be expanded upon, the basic definition was accurate and covered more than just integers and strings. This could point towards a potential improvement in recognizing the adequacy of the definition provided.
#
# 3. **Variable Declaration Evaluation (Score: B)**
#    - The evaluator noted that the answer could elaborate more on scope and types of declarations, but the basic concept was well addressed. Depending on the depth expected, a score of A could be justified if the foundational understanding was deemed sufficient.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**
#    - Similar to the previous point, while the evaluator mentioned the need for more implications on control flow, the main difference was correctly identified. This could also suggest that a deeper understanding was present, warranting a higher score.
#
# In summary, while the evaluations are generally accurate, there are some instances where the grades assigned may not fully reflect the level of understanding demonstrated in the answers. An adjustment in a couple of scores could more accurately represent the comprehension shown in each response.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation provided appears to be mostly coherent and accurate, but there are some areas where the understanding of the evaluator can be further scrutinized.
#
# 1. **Prototype Program Evaluation (Score: B)**
#    - The reason provided mentions a lack of detail on how prototypes are developed and their iterative nature. It could be argued that the evaluation could be more nuanced by recognizing that while the initial answer did lack detail, it still conveyed a fundamental understanding of the role of prototypes. Thus, a score of A may be more appropriate.
#
# 2. **Variable Evaluation (Score: C)**
#    - The evaluator states that the answer gives a partial definition and lacks depth. However, the cited paragraph does mention that a variable is a symbolic name associated with a value and can hold different data types. While it could certainly be expanded upon, the basic definition was accurate and covered more than just integers and strings. This could point towards a potential improvement in recognizing the adequacy of the definition provided.
#
# 3. **Variable Declaration Evaluation (Score: B)**
#    - The evaluator noted that the answer could elaborate more on scope and types of declarations, but the basic concept was well addressed. Depending on the depth expected, a score of A could be justified if the foundational understanding was deemed sufficient.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**
#    - Similar to the previous point, while the evaluator mentioned the need for more implications on control flow, the main difference was correctly identified. This could also suggest that a deeper understanding was present, warranting a higher score.
#
# In summary, while the evaluations are generally accurate, there are some instances where the grades assigned may not fully reflect the level of understanding demonstrated in the answers. An adjustment in a couple of scores could more accurately represent the comprehension shown in each response.
# ================================== Ai Message ==================================
#
# The evaluation provided appears to be well thought out and indicates a careful consideration of each response. However, it does seem that the evaluator may have missed certain nuances in the understanding of the material, particularly regarding the appropriateness of the scores assigned based on the depth and accuracy of the answers.
#
# 1. **Prototype Program Evaluation (Score: B)**: The evaluator's reasoning suggests a lack of recognition for the fundamental understanding conveyed in the response. Acknowledging the importance of detail in prototype development is valid, but given the foundational understanding present, a score of A could indeed be more suitable.
#
# 2. **Variable Evaluation (Score: C)**: Here, the evaluator correctly identifies gaps in depth but seems to overlook the accuracy of the basic definition provided. Since the definition included important aspects of variables, a higher score may be justified. This indicates a potential gap in recognizing when a foundational response is adequate.
#
# 3. **Variable Declaration Evaluation (Score: B)**: The evaluator points out areas for elaboration, but similar to the previous evaluations, the fundamental concept seems well addressed. This suggests that the evaluator could reconsider the overall comprehension demonstrated in the answer.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**: The evaluator mentions the need for more implications on control flow, yet the core distinction was correctly identified. This again points to a possible oversight in fully appreciating the accuracy of the response.
#
# In conclusion, while the evaluations are generally coherent and mostly accurate, the evaluator may benefit from a deeper analysis of the responses' foundational understanding. Adjusting a few scores to reflect the adequacy of the definitions and the understanding demonstrated would enhance the overall evaluation.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation provided appears to be well thought out and indicates a careful consideration of each response. However, it does seem that the evaluator may have missed certain nuances in the understanding of the material, particularly regarding the appropriateness of the scores assigned based on the depth and accuracy of the answers.
#
# 1. **Prototype Program Evaluation (Score: B)**: The evaluator's reasoning suggests a lack of recognition for the fundamental understanding conveyed in the response. Acknowledging the importance of detail in prototype development is valid, but given the foundational understanding present, a score of A could indeed be more suitable.
#
# 2. **Variable Evaluation (Score: C)**: Here, the evaluator correctly identifies gaps in depth but seems to overlook the accuracy of the basic definition provided. Since the definition included important aspects of variables, a higher score may be justified. This indicates a potential gap in recognizing when a foundational response is adequate.
#
# 3. **Variable Declaration Evaluation (Score: B)**: The evaluator points out areas for elaboration, but similar to the previous evaluations, the fundamental concept seems well addressed. This suggests that the evaluator could reconsider the overall comprehension demonstrated in the answer.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**: The evaluator mentions the need for more implications on control flow, yet the core distinction was correctly identified. This again points to a possible oversight in fully appreciating the accuracy of the response.
#
# In conclusion, while the evaluations are generally coherent and mostly accurate, the evaluator may benefit from a deeper analysis of the responses' foundational understanding. Adjusting a few scores to reflect the adequacy of the definitions and the understanding demonstrated would enhance the overall evaluation.
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a thoughtful approach, but there are indeed some gaps in the understanding of the evaluator, particularly regarding the appropriateness of the scores assigned.
#
# 1. **Prototype Program Evaluation (Score: B)**: The evaluation suggests that the fundamental understanding was not fully recognized. The argument for an A score is valid, as the response seems to convey a solid grasp of prototype development. This indicates that the evaluator could have placed more emphasis on the foundational understanding present in the response.
#
# 2. **Variable Evaluation (Score: C)**: While the evaluator correctly identifies gaps, they may have underestimated the accuracy of the definition provided. The response contained key elements that indicate a basic grasp of the concept, which could warrant a higher score. This reflects a potential inconsistency in evaluating foundational knowledge.
#
# 3. **Variable Declaration Evaluation (Score: B)**: The evaluator's comments about the need for elaboration are valid, but the fundamental concept appears to be well addressed. This suggests that the evaluator may not have fully appreciated the adequacy of the response, indicating a need for a more nuanced assessment of understanding.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**: The evaluator's focus on control flow implications highlights an important aspect of the response, yet the core distinction was made accurately. This again points to a need for the evaluator to better recognize the accuracy of the foundational understanding presented.
#
# Overall, while the evaluations are coherent and largely accurate, it seems the evaluator could benefit from a deeper analysis of the responses' foundational understanding. Adjusting scores to reflect the adequacy of the definitions and comprehension demonstrated would improve the overall evaluation.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a thoughtful approach, but there are indeed some gaps in the understanding of the evaluator, particularly regarding the appropriateness of the scores assigned.
#
# 1. **Prototype Program Evaluation (Score: B)**: The evaluation suggests that the fundamental understanding was not fully recognized. The argument for an A score is valid, as the response seems to convey a solid grasp of prototype development. This indicates that the evaluator could have placed more emphasis on the foundational understanding present in the response.
#
# 2. **Variable Evaluation (Score: C)**: While the evaluator correctly identifies gaps, they may have underestimated the accuracy of the definition provided. The response contained key elements that indicate a basic grasp of the concept, which could warrant a higher score. This reflects a potential inconsistency in evaluating foundational knowledge.
#
# 3. **Variable Declaration Evaluation (Score: B)**: The evaluator's comments about the need for elaboration are valid, but the fundamental concept appears to be well addressed. This suggests that the evaluator may not have fully appreciated the adequacy of the response, indicating a need for a more nuanced assessment of understanding.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**: The evaluator's focus on control flow implications highlights an important aspect of the response, yet the core distinction was made accurately. This again points to a need for the evaluator to better recognize the accuracy of the foundational understanding presented.
#
# Overall, while the evaluations are coherent and largely accurate, it seems the evaluator could benefit from a deeper analysis of the responses' foundational understanding. Adjusting scores to reflect the adequacy of the definitions and comprehension demonstrated would improve the overall evaluation.
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a thoughtful approach, but there are indeed some gaps in the understanding of the evaluator, particularly regarding the appropriateness of the scores assigned.
#
# 1. **Prototype Program Evaluation (Score: B)**: The evaluation suggests that the fundamental understanding was not fully recognized. The argument for an A score is valid, as the response seems to convey a solid grasp of prototype development. This indicates that the evaluator could have placed more emphasis on the foundational understanding present in the response.
#
# 2. **Variable Evaluation (Score: C)**: While the evaluator correctly identifies gaps, they may have underestimated the accuracy of the definition provided. The response contained key elements that indicate a basic grasp of the concept, which could warrant a higher score. This reflects a potential inconsistency in evaluating foundational knowledge.
#
# 3. **Variable Declaration Evaluation (Score: B)**: The evaluator's comments about the need for elaboration are valid, but the fundamental concept appears to be well addressed. This suggests that the evaluator may not have fully appreciated the adequacy of the response, indicating a need for a more nuanced assessment of understanding.
#
# 4. **While vs. Do...While Statement Evaluation (Score: B)**: The evaluator's focus on control flow implications highlights an important aspect of the response, yet the core distinction was made accurately. This again points to a need for the evaluator to better recognize the accuracy of the foundational understanding presented.
#
# Overall, while the evaluations are coherent and largely accurate, it seems the evaluator could benefit from a deeper analysis of the responses' foundational understanding. Adjusting scores to reflect the adequacy of the definitions and comprehension demonstrated would improve the overall evaluation.

# %% [markdown]
# #### Run Benchmarks

# %%
from agent.graphs import *

def save_json(data, file_name):
    with open(file_name, 'w') as f:
        json.dump(data, f, indent=4)

one_shot_final_responses = {}
graph = one_shot_graph()
for student_id in benchmark_lesson_1.keys():    
    exec_state = OverallState(
         user_input = {"open_questions": benchmark_lesson_1[student_id]},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    messages=[]
    )
    try:
        grade_dict = execute_graph(exec_state, graph)
    except Exception as e:
            grade_dict = {"ERROR": e}
    one_shot_final_responses[student_id] = grade_dict

save_json(one_shot_final_responses, 'data/gpt_4o_one_shot_final_responses.json')
# Out:
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student identifies that prototypes address high-risk problems and demonstrate feasibility. However, they could elaborate on how prototypes provide early feedback and help refine requirements.","cited_paragraph":"Prototyping is used to explore feasibility, gather early feedback, and test assumptions in problem-solving, allowing for adjustments before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"A","reason":"The student correctly identifies multiple aspects of the SDLC influenced by testing, such as design, production, and coding, showing a comprehensive understanding of the testing phase's impact.","cited_paragraph":"The testing phase influences the design, coding, and production stages by identifying issues that may require redesign or code modifications, ensuring quality and functionality."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student accurately describes key OOP advantages: modularity, reusability, debugging, security, inheritance, and polymorphism. This demonstrates a nuanced understanding of OOP's benefits.","cited_paragraph":"Object-oriented programming offers advantages like modularity, reusability, ease of debugging, security, and supports inheritance and polymorphism, leading to efficient and maintainable code."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies 'int main()' as the entry point for C++ program execution, demonstrating an understanding of program structure.","cited_paragraph":"In C++, the 'int main()' function is the entry point where program execution begins, serving as the starting point for all C++ applications."},{"question":"What is a variable?","score":"C","reason":"The student provides a limited definition of variables as data types (integer or string) but lacks explanation of their purpose or role in programming.","cited_paragraph":"A variable is a storage location identified by a name, used to hold data in a program that can be modified during execution. It can represent various data types, such as integers, strings, etc."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student explains that variables can be declared before use and suggests good practice, but the explanation could be more precise about scope and initialization.","cited_paragraph":"In C++, variables can be declared at the beginning of a block or as needed, with good practice typically favoring declaration near the start of a block for clarity and scope management."},{"question":"What is the main difference between a while and a do...while statement?","score":"C","reason":"The student confuses the 'do' and 'do...while' statement operations, indicating a partial understanding of loop control flow concepts.","cited_paragraph":"The 'while' loop evaluates the condition before executing the code block, potentially zero times. The 'do...while' loop executes the code block once before evaluating the condition, ensuring at least one execution."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student identifies that prototypes address high-risk problems and demonstrate feasibility. However, they could elaborate on how prototypes provide early feedback and help refine requirements.","cited_paragraph":"Prototyping is used to explore feasibility, gather early feedback, and test assumptions in problem-solving, allowing for adjustments before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"A","reason":"The student correctly identifies multiple aspects of the SDLC influenced by testing, such as design, production, and coding, showing a comprehensive understanding of the testing phase's impact.","cited_paragraph":"The testing phase influences the design, coding, and production stages by identifying issues that may require redesign or code modifications, ensuring quality and functionality."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student accurately describes key OOP advantages: modularity, reusability, debugging, security, inheritance, and polymorphism. This demonstrates a nuanced understanding of OOP's benefits.","cited_paragraph":"Object-oriented programming offers advantages like modularity, reusability, ease of debugging, security, and supports inheritance and polymorphism, leading to efficient and maintainable code."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies 'int main()' as the entry point for C++ program execution, demonstrating an understanding of program structure.","cited_paragraph":"In C++, the 'int main()' function is the entry point where program execution begins, serving as the starting point for all C++ applications."},{"question":"What is a variable?","score":"C","reason":"The student provides a limited definition of variables as data types (integer or string) but lacks explanation of their purpose or role in programming.","cited_paragraph":"A variable is a storage location identified by a name, used to hold data in a program that can be modified during execution. It can represent various data types, such as integers, strings, etc."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student explains that variables can be declared before use and suggests good practice, but the explanation could be more precise about scope and initialization.","cited_paragraph":"In C++, variables can be declared at the beginning of a block or as needed, with good practice typically favoring declaration near the start of a block for clarity and scope management."},{"question":"What is the main difference between a while and a do...while statement?","score":"C","reason":"The student confuses the 'do' and 'do...while' statement operations, indicating a partial understanding of loop control flow concepts.","cited_paragraph":"The 'while' loop evaluates the condition before executing the code block, potentially zero times. The 'do...while' loop executes the code block once before evaluating the condition, ensuring at least one execution."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student mentions simulating behavior, which is a part of prototyping. However, they do not fully address its role in identifying issues early or refining requirements.","cited_paragraph":"Prototyping in problem solving involves creating an early model of the final product to understand requirements better, test ideas, and identify potential problems before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"B","reason":"The student correctly identifies stages influenced by testing, but does not mention design or requirements, which are also affected.","cited_paragraph":"The testing phase in the SDLC can influence the design, coding, and maintenance stages by identifying defects and ensuring requirements are met."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student correctly identifies reusability and ease of maintenance as main advantages, which are central to OOP.","cited_paragraph":"Object-oriented programming offers advantages such as reusability, ease of maintenance, and scalability due to features like inheritance and polymorphism."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies 'main' as the entry point for C++ program execution.","cited_paragraph":"In C++, the 'main' function is the entry point where execution begins."},{"question":"What is a variable?","score":"A","reason":"The student accurately defines a variable as a block of memory that holds data, which is a core concept.","cited_paragraph":"A variable is a storage location in memory with a specific type, used to hold data."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly identifies global and local declarations, but the mention of 'FOR statements' is slightly misleading as it applies generally to blocks or scopes.","cited_paragraph":"Variables in C++ can be declared globally for the entire program or locally within functions or blocks, determining their scope and lifetime."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student accurately describes the execution flow difference between 'while' and 'do...while' loops.","cited_paragraph":"A 'while' loop evaluates the condition before executing the loop body, whereas a 'do...while' loop evaluates the condition after executing the loop body, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student mentions simulating behavior, which is a part of prototyping. However, they do not fully address its role in identifying issues early or refining requirements.","cited_paragraph":"Prototyping in problem solving involves creating an early model of the final product to understand requirements better, test ideas, and identify potential problems before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"B","reason":"The student correctly identifies stages influenced by testing, but does not mention design or requirements, which are also affected.","cited_paragraph":"The testing phase in the SDLC can influence the design, coding, and maintenance stages by identifying defects and ensuring requirements are met."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student correctly identifies reusability and ease of maintenance as main advantages, which are central to OOP.","cited_paragraph":"Object-oriented programming offers advantages such as reusability, ease of maintenance, and scalability due to features like inheritance and polymorphism."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies 'main' as the entry point for C++ program execution.","cited_paragraph":"In C++, the 'main' function is the entry point where execution begins."},{"question":"What is a variable?","score":"A","reason":"The student accurately defines a variable as a block of memory that holds data, which is a core concept.","cited_paragraph":"A variable is a storage location in memory with a specific type, used to hold data."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly identifies global and local declarations, but the mention of 'FOR statements' is slightly misleading as it applies generally to blocks or scopes.","cited_paragraph":"Variables in C++ can be declared globally for the entire program or locally within functions or blocks, determining their scope and lifetime."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student accurately describes the execution flow difference between 'while' and 'do...while' loops.","cited_paragraph":"A 'while' loop evaluates the condition before executing the loop body, whereas a 'do...while' loop evaluates the condition after executing the loop body, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"C","reason":"The student identifies that a prototype simulates behavior, but the answer lacks depth regarding how prototyping aids in problem-solving and iterative development.","cited_paragraph":"A prototype program is an early version of a software application created to test specific features and gather feedback, which helps in identifying potential issues and refining requirements."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"B","reason":"The student correctly identifies later stages of the SDLC influenced by testing but does not address earlier phases where testing feedback might also have an impact, such as in planning or design.","cited_paragraph":"The testing phase in the SDLC influences various stages, particularly the construction and transition phases, but insights gained can also impact earlier phases, including design and requirement gathering."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student demonstrates a thorough understanding of key OOP concepts: encapsulation, inheritance, and polymorphism, and correctly explains reusability.","cited_paragraph":"Object-oriented programming provides several advantages, including encapsulation (hiding internal state), inheritance (reusing existing code), and polymorphism (dynamic method execution)."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student's answer is accurate and directly addresses the question regarding the starting point of execution in C++ programs.","cited_paragraph":"In C++ programs, execution begins at the function 'int main()', which serves as the entry point."},{"question":"What is a variable?","score":"B","reason":"The student correctly describes a variable but could enhance the explanation by mentioning that a variable can hold different types of data and is used for various operations.","cited_paragraph":"A variable is a storage location identified by a memory address and symbolic name, which holds data that can be modified during program execution."},{"question":"Where are variables declared in a C++ program?","score":"C","reason":"The student gives a general idea about variable declaration but overlooks the flexibility of declaring variables within different scopes, such as local or global within a C++ program.","cited_paragraph":"Variables in C++ can be declared in different scopes, typically at the beginning of a block or globally, depending on where they are needed within the program."},{"question":"What is the main difference between a while and a do...while statement?","score":"B","reason":"The student correctly identifies the primary difference in execution between the two loops but mistakenly refers to 'do' instead of 'while'. This minor error doesn't significantly detract from understanding.","cited_paragraph":"The 'while' loop tests its condition before executing the loop's body, whereas the 'do...while' loop executes the body once before evaluating the condition."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"C","reason":"The student identifies that a prototype simulates behavior, but the answer lacks depth regarding how prototyping aids in problem-solving and iterative development.","cited_paragraph":"A prototype program is an early version of a software application created to test specific features and gather feedback, which helps in identifying potential issues and refining requirements."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"B","reason":"The student correctly identifies later stages of the SDLC influenced by testing but does not address earlier phases where testing feedback might also have an impact, such as in planning or design.","cited_paragraph":"The testing phase in the SDLC influences various stages, particularly the construction and transition phases, but insights gained can also impact earlier phases, including design and requirement gathering."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student demonstrates a thorough understanding of key OOP concepts: encapsulation, inheritance, and polymorphism, and correctly explains reusability.","cited_paragraph":"Object-oriented programming provides several advantages, including encapsulation (hiding internal state), inheritance (reusing existing code), and polymorphism (dynamic method execution)."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student's answer is accurate and directly addresses the question regarding the starting point of execution in C++ programs.","cited_paragraph":"In C++ programs, execution begins at the function 'int main()', which serves as the entry point."},{"question":"What is a variable?","score":"B","reason":"The student correctly describes a variable but could enhance the explanation by mentioning that a variable can hold different types of data and is used for various operations.","cited_paragraph":"A variable is a storage location identified by a memory address and symbolic name, which holds data that can be modified during program execution."},{"question":"Where are variables declared in a C++ program?","score":"C","reason":"The student gives a general idea about variable declaration but overlooks the flexibility of declaring variables within different scopes, such as local or global within a C++ program.","cited_paragraph":"Variables in C++ can be declared in different scopes, typically at the beginning of a block or globally, depending on where they are needed within the program."},{"question":"What is the main difference between a while and a do...while statement?","score":"B","reason":"The student correctly identifies the primary difference in execution between the two loops but mistakenly refers to 'do' instead of 'while'. This minor error doesn't significantly detract from understanding.","cited_paragraph":"The 'while' loop tests its condition before executing the loop's body, whereas the 'do...while' loop executes the body once before evaluating the condition."}]}
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "B",
#             "reason": "The student identifies that a prototype simulates behavior, which is correct, but does not explicitly link this to iterative development and feedback in problem-solving.",
#             "cited_paragraph": "Prototyping involves creating an early model of a software application to simulate its functionality and gather user feedback. It aids in problem-solving by allowing developers to explore ideas and refine solutions before full-scale development."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "C",
#             "reason": "The student lists some stages correctly but misses the analysis and design stages, which are also influenced by testing results.",
#             "cited_paragraph": "The testing phase in the SDLC influences several stages, including requirements analysis, design, implementation, and maintenance, as it provides feedback that leads to refinements or changes."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "B",
#             "reason": "The student correctly mentions reusability and maintenance, but omits polymorphism and inheritance as key advantages.",
#             "cited_paragraph": "Object-oriented programming offers advantages like code reusability through inheritance, easier maintenance and modifications, and flexibility through polymorphism, which allows for dynamic method invocation."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "A",
#             "reason": "The student correctly identifies 'the main method' as the entry point for C++ program execution.",
#             "cited_paragraph": "In C++ programs, execution begins in the 'main()' function. This is the starting point of every C++ application."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "A",
#             "reason": "The student accurately describes a variable as a location in memory where a value can be stored.",
#             "cited_paragraph": "A variable is a symbolic name for a storage location in memory that holds a value which can be changed during program execution."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "C",
#             "reason": "The student only states 'inside the method,' overlooking that variables can also be declared globally or within other scopes.",
#             "cited_paragraph": "In C++, variables can be declared inside a function (local scope), outside all functions (global scope), or within class definitions (member variables)."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "A",
#             "reason": "The student correctly identifies that a do...while loop executes at least once, which is the main difference.",
#             "cited_paragraph": "The main difference between a 'while' loop and a 'do...while' loop is that the 'do...while' loop executes its body at least once before checking its condition, whereas a 'while' loop checks its condition before executing."
#         }
#     ]
# }
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "B",
#             "reason": "The student identifies that a prototype simulates behavior, which is correct, but does not explicitly link this to iterative development and feedback in problem-solving.",
#             "cited_paragraph": "Prototyping involves creating an early model of a software application to simulate its functionality and gather user feedback. It aids in problem-solving by allowing developers to explore ideas and refine solutions before full-scale development."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "C",
#             "reason": "The student lists some stages correctly but misses the analysis and design stages, which are also influenced by testing results.",
#             "cited_paragraph": "The testing phase in the SDLC influences several stages, including requirements analysis, design, implementation, and maintenance, as it provides feedback that leads to refinements or changes."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "B",
#             "reason": "The student correctly mentions reusability and maintenance, but omits polymorphism and inheritance as key advantages.",
#             "cited_paragraph": "Object-oriented programming offers advantages like code reusability through inheritance, easier maintenance and modifications, and flexibility through polymorphism, which allows for dynamic method invocation."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "A",
#             "reason": "The student correctly identifies 'the main method' as the entry point for C++ program execution.",
#             "cited_paragraph": "In C++ programs, execution begins in the 'main()' function. This is the starting point of every C++ application."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "A",
#             "reason": "The student accurately describes a variable as a location in memory where a value can be stored.",
#             "cited_paragraph": "A variable is a symbolic name for a storage location in memory that holds a value which can be changed during program execution."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "C",
#             "reason": "The student only states 'inside the method,' overlooking that variables can also be declared globally or within other scopes.",
#             "cited_paragraph": "In C++, variables can be declared inside a function (local scope), outside all functions (global scope), or within class definitions (member variables)."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "A",
#             "reason": "The student correctly identifies that a do...while loop executes at least once, which is the main difference.",
#             "cited_paragraph": "The main difference between a 'while' loop and a 'do...while' loop is that the 'do...while' loop executes its body at least once before checking its condition, whereas a 'while' loop checks its condition before executing."
#         }
#     ]
# }
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The answer captures the basic purpose of prototyping by mentioning a starting point, but lacks detail on iterative testing or feedback loops in problem solving.","cited_paragraph":"Prototyping involves creating an early model of a program to test ideas and refine functionality. It allows developers to experiment with design and functionality before full-scale development, facilitating problem solving by identifying issues early."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"C","reason":"The student identifies stages but misses key stages like Requirements and Design, influenced by testing insights. Thus, understanding is partial.","cited_paragraph":"Testing influences various stages of the Software Development Life Cycle (SDLC) including Requirements, Design, Implementation, and Maintenance by providing feedback that can lead to revisions and improvements."},{"question":"What are the main advantages associated with object-oriented programming?","score":"C","reason":"The student mentions easier debugging but misses key advantages like reusability, inheritance, and polymorphism, which are central to OOP.","cited_paragraph":"Object-oriented programming offers advantages such as reusability through inheritance, flexibility via polymorphism, and modularity, which simplifies debugging and maintenance."},{"question":"Where do C++ programs begin to execute?","score":"F","reason":"The answer 'at the root' is incorrect. C++ programs begin execution at the 'int main()' function, which is fundamental to understanding C++ program structure.","cited_paragraph":"In C++, the 'main()' function is the entry point for program execution. Every C++ program must have a 'main()' function, which is where execution begins."},{"question":"What is a variable?","score":"B","reason":"The answer is correct in stating that a variable can assume different values, but lacks explanation about variables being named storage locations or their types.","cited_paragraph":"A variable is a named storage location in memory that holds a value, which can change during program execution. Variables have types that determine the kind of data they can store."},{"question":"Where are variables declared in a C++ program?","score":"C","reason":"The answer 'at the top' is overly simplistic. Variables in C++ can be declared at the top, within functions, or blocks, reflecting partial understanding.","cited_paragraph":"In C++, variables can be declared at the beginning of a block or function, or globally at the top of a file. The scope of the variable depends on where it is declared."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student correctly identifies that 'do...while' executes at least once, whereas 'while' may not if the condition is initially false, showing thorough understanding.","cited_paragraph":"The 'while' loop evaluates the condition before executing, possibly skipping entirely if false. The 'do...while' loop executes once before evaluating the condition, ensuring at least one iteration."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The answer captures the basic purpose of prototyping by mentioning a starting point, but lacks detail on iterative testing or feedback loops in problem solving.","cited_paragraph":"Prototyping involves creating an early model of a program to test ideas and refine functionality. It allows developers to experiment with design and functionality before full-scale development, facilitating problem solving by identifying issues early."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"C","reason":"The student identifies stages but misses key stages like Requirements and Design, influenced by testing insights. Thus, understanding is partial.","cited_paragraph":"Testing influences various stages of the Software Development Life Cycle (SDLC) including Requirements, Design, Implementation, and Maintenance by providing feedback that can lead to revisions and improvements."},{"question":"What are the main advantages associated with object-oriented programming?","score":"C","reason":"The student mentions easier debugging but misses key advantages like reusability, inheritance, and polymorphism, which are central to OOP.","cited_paragraph":"Object-oriented programming offers advantages such as reusability through inheritance, flexibility via polymorphism, and modularity, which simplifies debugging and maintenance."},{"question":"Where do C++ programs begin to execute?","score":"F","reason":"The answer 'at the root' is incorrect. C++ programs begin execution at the 'int main()' function, which is fundamental to understanding C++ program structure.","cited_paragraph":"In C++, the 'main()' function is the entry point for program execution. Every C++ program must have a 'main()' function, which is where execution begins."},{"question":"What is a variable?","score":"B","reason":"The answer is correct in stating that a variable can assume different values, but lacks explanation about variables being named storage locations or their types.","cited_paragraph":"A variable is a named storage location in memory that holds a value, which can change during program execution. Variables have types that determine the kind of data they can store."},{"question":"Where are variables declared in a C++ program?","score":"C","reason":"The answer 'at the top' is overly simplistic. Variables in C++ can be declared at the top, within functions, or blocks, reflecting partial understanding.","cited_paragraph":"In C++, variables can be declared at the beginning of a block or function, or globally at the top of a file. The scope of the variable depends on where it is declared."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student correctly identifies that 'do...while' executes at least once, whereas 'while' may not if the condition is initially false, showing thorough understanding.","cited_paragraph":"The 'while' loop evaluates the condition before executing, possibly skipping entirely if false. The 'do...while' loop executes once before evaluating the condition, ensuring at least one iteration."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student understands that prototyping involves simulating parts of the problem, but lacks detail on how this aids in iterative development and validation.","cited_paragraph":"Prototyping is a method used in problem solving to create a preliminary version of a system. It helps in understanding requirements better, testing feasibility, and refining functionality through iteration."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"D","reason":"The student only mentions 'refining,' which is vague and does not cover the various stages like design, development, and maintenance that testing influences.","cited_paragraph":"The testing phase of the software development life cycle (SDLC) influences several stages, including requirements refinement, design adjustments, and code corrections. It helps ensure that the final product meets the initial requirements and works as intended."},{"question":"What are the main advantages associated with object-oriented programming?","score":"C","reason":"The student mentions encapsulation and manipulation of data but misses key concepts such as inheritance, polymorphism, and reusability.","cited_paragraph":"Object-oriented programming (OOP) offers several advantages: encapsulation, which hides internal state; inheritance, which promotes code reuse; and polymorphism, which allows for flexibility in using different classes interchangeably."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies the main() function as the entry point for C++ program execution, demonstrating a clear understanding.","cited_paragraph":"In C++, the execution of a program begins with the 'int main()' function, which serves as the entry point for the program."},{"question":"What is a variable?","score":"C","reason":"The student describes a variable as a memory pointer, which is a partial understanding. Variables are actually named storage locations in memory, not just pointers.","cited_paragraph":"A variable in programming is a named storage location in memory that holds a value. It is not a pointer itself but rather a reference to a data type that can be manipulated during program execution."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly distinguishes between global and local variables but makes a minor error regarding the location for declaring global variables, which are usually outside any function.","cited_paragraph":"In C++, variables can be declared globally, outside of any function, or locally, within a function. Global variables are accessible throughout the program, while local variables are only accessible within their respective functions."},{"question":"What is the main difference between a while and a do...while statement?","score":"B","reason":"The student correctly identifies that a do...while loop runs at least once, but the explanation of the while loop is incomplete.","cited_paragraph":"The main difference between a 'while' and a 'do...while' loop is that in a 'while' loop, the condition is tested before the loop body executes, whereas in a 'do...while' loop, the condition is tested after the loop body executes, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student understands that prototyping involves simulating parts of the problem, but lacks detail on how this aids in iterative development and validation.","cited_paragraph":"Prototyping is a method used in problem solving to create a preliminary version of a system. It helps in understanding requirements better, testing feasibility, and refining functionality through iteration."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"D","reason":"The student only mentions 'refining,' which is vague and does not cover the various stages like design, development, and maintenance that testing influences.","cited_paragraph":"The testing phase of the software development life cycle (SDLC) influences several stages, including requirements refinement, design adjustments, and code corrections. It helps ensure that the final product meets the initial requirements and works as intended."},{"question":"What are the main advantages associated with object-oriented programming?","score":"C","reason":"The student mentions encapsulation and manipulation of data but misses key concepts such as inheritance, polymorphism, and reusability.","cited_paragraph":"Object-oriented programming (OOP) offers several advantages: encapsulation, which hides internal state; inheritance, which promotes code reuse; and polymorphism, which allows for flexibility in using different classes interchangeably."},{"question":"Where do C++ programs begin to execute?","score":"A","reason":"The student correctly identifies the main() function as the entry point for C++ program execution, demonstrating a clear understanding.","cited_paragraph":"In C++, the execution of a program begins with the 'int main()' function, which serves as the entry point for the program."},{"question":"What is a variable?","score":"C","reason":"The student describes a variable as a memory pointer, which is a partial understanding. Variables are actually named storage locations in memory, not just pointers.","cited_paragraph":"A variable in programming is a named storage location in memory that holds a value. It is not a pointer itself but rather a reference to a data type that can be manipulated during program execution."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly distinguishes between global and local variables but makes a minor error regarding the location for declaring global variables, which are usually outside any function.","cited_paragraph":"In C++, variables can be declared globally, outside of any function, or locally, within a function. Global variables are accessible throughout the program, while local variables are only accessible within their respective functions."},{"question":"What is the main difference between a while and a do...while statement?","score":"B","reason":"The student correctly identifies that a do...while loop runs at least once, but the explanation of the while loop is incomplete.","cited_paragraph":"The main difference between a 'while' and a 'do...while' loop is that in a 'while' loop, the condition is tested before the loop body executes, whereas in a 'do...while' loop, the condition is tested after the loop body executes, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "B",
#             "reason": "The answer correctly identifies the purpose of a prototype in providing a basic framework, but it lacks detail on how prototyping specifically aids iterative problem solving.",
#             "cited_paragraph": "Prototyping serves as an early model to test ideas and functionalities, allowing for iterative refinement and feedback integration, which enhances problem solving by identifying potential issues early."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "C",
#             "reason": "The answer acknowledges the impact of testing on finalization but overlooks its influence on earlier stages like design and development through validation and feedback loops.",
#             "cited_paragraph": "The testing phase influences the software development life cycle by identifying defects and areas for improvement, affecting phases like design, development, and maintenance through feedback and validation."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "B",
#             "reason": "The answer highlights modularity and reusability, key OOP advantages, but it could expand on how inheritance and polymorphism contribute to these benefits.",
#             "cited_paragraph": "Object-oriented programming offers advantages such as modularity, reusability, and scalability through concepts like inheritance and polymorphism, which allow for code reuse and easier maintenance."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "A",
#             "reason": "The answer is concise and correct, accurately stating that execution starts at the 'main' function.",
#             "cited_paragraph": "In C++ program structure, execution begins at the 'main()' function, which serves as the entry point for program execution."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "B",
#             "reason": "The answer provides a general understanding of a variable but conflates memory address with the concept, and the mathematical perspective is less relevant.",
#             "cited_paragraph": "A variable is a named storage location in memory, used to hold data that can be modified during program execution. It is associated with a data type that determines the kind of values it can store."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "C",
#             "reason": "The answer correctly notes variables are often declared at the beginning, but it lacks clarity on scope and placement specifics, like inside functions or at global scope.",
#             "cited_paragraph": "In C++, variables can be declared at various points, including at the beginning of a program, within functions, or globally, depending on their intended scope and usage."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "A",
#             "reason": "The answer correctly describes the functional difference between while and do...while loops concerning their execution and testing order.",
#             "cited_paragraph": "A 'while' loop evaluates the condition before executing the loop body, while a 'do...while' loop executes the loop body once before evaluating the condition."
#         }
#     ]
# }
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "B",
#             "reason": "The answer correctly identifies the purpose of a prototype in providing a basic framework, but it lacks detail on how prototyping specifically aids iterative problem solving.",
#             "cited_paragraph": "Prototyping serves as an early model to test ideas and functionalities, allowing for iterative refinement and feedback integration, which enhances problem solving by identifying potential issues early."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "C",
#             "reason": "The answer acknowledges the impact of testing on finalization but overlooks its influence on earlier stages like design and development through validation and feedback loops.",
#             "cited_paragraph": "The testing phase influences the software development life cycle by identifying defects and areas for improvement, affecting phases like design, development, and maintenance through feedback and validation."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "B",
#             "reason": "The answer highlights modularity and reusability, key OOP advantages, but it could expand on how inheritance and polymorphism contribute to these benefits.",
#             "cited_paragraph": "Object-oriented programming offers advantages such as modularity, reusability, and scalability through concepts like inheritance and polymorphism, which allow for code reuse and easier maintenance."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "A",
#             "reason": "The answer is concise and correct, accurately stating that execution starts at the 'main' function.",
#             "cited_paragraph": "In C++ program structure, execution begins at the 'main()' function, which serves as the entry point for program execution."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "B",
#             "reason": "The answer provides a general understanding of a variable but conflates memory address with the concept, and the mathematical perspective is less relevant.",
#             "cited_paragraph": "A variable is a named storage location in memory, used to hold data that can be modified during program execution. It is associated with a data type that determines the kind of values it can store."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "C",
#             "reason": "The answer correctly notes variables are often declared at the beginning, but it lacks clarity on scope and placement specifics, like inside functions or at global scope.",
#             "cited_paragraph": "In C++, variables can be declared at various points, including at the beginning of a program, within functions, or globally, depending on their intended scope and usage."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "A",
#             "reason": "The answer correctly describes the functional difference between while and do...while loops concerning their execution and testing order.",
#             "cited_paragraph": "A 'while' loop evaluates the condition before executing the loop body, while a 'do...while' loop executes the loop body once before evaluating the condition."
#         }
#     ]
# }
# ================================== Ai Message ==================================
#
# ```json
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "B",
#             "reason": "The student correctly identifies that a prototype is used to illustrate solutions, but incorrectly places it specifically in the Specification phase. Prototyping can occur in various stages, not just Specification.",
#             "cited_paragraph": "Prototyping in problem solving involves creating an early model of a program to test and refine ideas before full-scale development."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "C",
# ...
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student demonstrates a basic understanding of prototyping by mentioning its role in simulating parts of the final program, but lacks detail on iterative development and refining solutions.","cited_paragraph":"Prototyping involves creating a preliminary model of a program to explore ideas and refine functionality, often used to troubleshoot and optimize problem-solving before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"C","reason":"The answer is vague and does not specify which stages, such as design, implementation, or maintenance, are influenced by testing.","cited_paragraph":"The testing stage influences various stages in the software development life cycle (SDLC), including design (through feedback), implementation (by identifying defects), and maintenance (by ensuring stability)."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student correctly identifies key OOP concepts: encapsulation, inheritance, and polymorphism, and explains them accurately, demonstrating a thorough understanding.","cited_paragraph":"Object-oriented programming offers advantages such as encapsulation (combining data and operations), inheritance (classes inheriting properties), and polymorphism (objects determining operations at runtime), enhancing code reuse and modularity."},{"question":"Where do C++ programs begin to execute?","score":"F","reason":"The answer is incorrect as C++ programs begin execution in the 'int main()' function, not the testing phase.","cited_paragraph":"In C++, program execution starts at the 'int main()' function, which serves as the entry point for the program."},{"question":"What is a variable?","score":"A","reason":"The student provides a precise and accurate definition of a variable, showing a clear understanding of its role in programming.","cited_paragraph":"A variable in programming is a reserved memory location to store values that a program can manipulate during execution."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly identifies local and global variables but inaccurately states that global variables are declared 'in the body' without specifying the global scope outside functions or classes.","cited_paragraph":"In C++, local variables are declared within functions or blocks, while global variables are declared outside any function, typically at the top of the file, to be accessible throughout the program."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student accurately describes the execution behavior of both loops, highlighting the key difference in their control flow.","cited_paragraph":"The 'while' loop evaluates its condition before executing the loop body, whereas the 'do...while' loop executes the body once before evaluating the condition, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {"evaluated_questions":[{"question":"What is the role of a prototype program in problem solving?","score":"B","reason":"The student demonstrates a basic understanding of prototyping by mentioning its role in simulating parts of the final program, but lacks detail on iterative development and refining solutions.","cited_paragraph":"Prototyping involves creating a preliminary model of a program to explore ideas and refine functionality, often used to troubleshoot and optimize problem-solving before full-scale development."},{"question":"What stages in the software life cycle are influenced by the testing stage?","score":"C","reason":"The answer is vague and does not specify which stages, such as design, implementation, or maintenance, are influenced by testing.","cited_paragraph":"The testing stage influences various stages in the software development life cycle (SDLC), including design (through feedback), implementation (by identifying defects), and maintenance (by ensuring stability)."},{"question":"What are the main advantages associated with object-oriented programming?","score":"A","reason":"The student correctly identifies key OOP concepts: encapsulation, inheritance, and polymorphism, and explains them accurately, demonstrating a thorough understanding.","cited_paragraph":"Object-oriented programming offers advantages such as encapsulation (combining data and operations), inheritance (classes inheriting properties), and polymorphism (objects determining operations at runtime), enhancing code reuse and modularity."},{"question":"Where do C++ programs begin to execute?","score":"F","reason":"The answer is incorrect as C++ programs begin execution in the 'int main()' function, not the testing phase.","cited_paragraph":"In C++, program execution starts at the 'int main()' function, which serves as the entry point for the program."},{"question":"What is a variable?","score":"A","reason":"The student provides a precise and accurate definition of a variable, showing a clear understanding of its role in programming.","cited_paragraph":"A variable in programming is a reserved memory location to store values that a program can manipulate during execution."},{"question":"Where are variables declared in a C++ program?","score":"B","reason":"The student correctly identifies local and global variables but inaccurately states that global variables are declared 'in the body' without specifying the global scope outside functions or classes.","cited_paragraph":"In C++, local variables are declared within functions or blocks, while global variables are declared outside any function, typically at the top of the file, to be accessible throughout the program."},{"question":"What is the main difference between a while and a do...while statement?","score":"A","reason":"The student accurately describes the execution behavior of both loops, highlighting the key difference in their control flow.","cited_paragraph":"The 'while' loop evaluates its condition before executing the loop body, whereas the 'do...while' loop executes the body once before evaluating the condition, ensuring it runs at least once."}]}
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "Prototyping in problem solving helps to create a preliminary version of a solution, allowing for testing and feedback before final implementation."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) can influence stages such as design, development, and maintenance, as it helps identify defects and areas for improvement."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "Object-oriented programming (OOP) advantages include inheritance, polymorphism, and reusability, which facilitate code organization, maintenance, and scalability."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "C++ programs begin execution at the 'int main()' function, which serves as the entry point for the program."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "A variable is a named storage location in memory that can hold a value and whose content can be changed during program execution."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "In C++, variables can be declared at the beginning of a function, globally outside all functions, or within a block, depending on their intended scope."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "The main difference is that a 'while' loop checks the condition before the loop body executes, whereas a 'do...while' loop checks the condition after executing the loop body at least once."
#         }
#     ]
# }
# ================================== Ai Message ==================================
#
# {
#     "evaluated_questions": [
#         {
#             "question": "What is the role of a prototype program in problem solving?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "Prototyping in problem solving helps to create a preliminary version of a solution, allowing for testing and feedback before final implementation."
#         },
#         {
#             "question": "What stages in the software life cycle are influenced by the testing stage?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) can influence stages such as design, development, and maintenance, as it helps identify defects and areas for improvement."
#         },
#         {
#             "question": "What are the main advantages associated with object-oriented programming?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "Object-oriented programming (OOP) advantages include inheritance, polymorphism, and reusability, which facilitate code organization, maintenance, and scalability."
#         },
#         {
#             "question": "Where do C++ programs begin to execute?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "C++ programs begin execution at the 'int main()' function, which serves as the entry point for the program."
#         },
#         {
#             "question": "What is a variable?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "A variable is a named storage location in memory that can hold a value and whose content can be changed during program execution."
#         },
#         {
#             "question": "Where are variables declared in a C++ program?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "In C++, variables can be declared at the beginning of a function, globally outside all functions, or within a block, depending on their intended scope."
#         },
#         {
#             "question": "What is the main difference between a while and a do...while statement?",
#             "score": "F",
#             "reason": "The student provided no answer, demonstrating a fundamental lack of understanding.",
#             "cited_paragraph": "The main difference is that a 'while' loop checks the condition before the loop body executes, whereas a 'do...while' loop checks the condition after executing the loop body at least once."
#         }
#     ]
# }

# %%
from agent.graphs import *
one_shot_reflection_final_responses = {}
graph = one_shot_with_reflection_graph()

for student_id in benchmark_lesson_1.keys():    
    exec_state = OverallState(
         user_input = {"open_questions": benchmark_lesson_1[student_id]},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    reflection_steps=0, #add it for reflection
    messages=[]
    )
    try:
        grade_dict = execute_graph(exec_state, graph)
    except Exception as e:
            grade_dict = {"ERROR": e}
    one_shot_reflection_final_responses[student_id] = grade_dict

save_json(one_shot_reflection_final_responses, 'data/one_shot_reflection_final_responses.json')
# Out:
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer demonstrates a mostly correct understanding of the role of prototypes in addressing high-risk problems and feasibility, but lacks depth in explaining how prototyping contributes to overall problem-solving processes.",
#       "cited_paragraph": "A prototype in problem solving serves to explore ideas and assess feasibility, allowing stakeholders to visualize and refine requirements. While the student mentions addressing high-risk problems, a more comprehensive explanation could include iterative feedback from users or stakeholders."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The response accurately identifies multiple stages affected by testing, including design, production, and coding, showing a thorough understanding of the software development life cycle (SDLC).",
#       "cited_paragraph": "Testing is a critical phase in the SDLC that informs and influences earlier stages like design and coding, as identified in the student's response. It is essential for ensuring the software meets quality standards and functions as intended."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a detailed explanation of the advantages of object-oriented programming, including modularity, reusability, ease of debugging, security, inheritance, and polymorphism, reflecting a nuanced understanding.",
#       "cited_paragraph": "Object-oriented programming promotes modularity and reusability, which facilitate easier maintenance and debugging. The mention of security and the specific benefits of inheritance and polymorphism further demonstrates a comprehensive grasp of the topic."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer correctly identifies that C++ programs start execution at 'int main()', showcasing a clear understanding of program structure.",
#       "cited_paragraph": "In C++, the execution of a program begins at the 'int main()' function, which is the entry point for all C++ programs, indicating a solid comprehension of C++ program structure."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The definition provided is partial, as it describes variables only in terms of data types without explaining their purpose or role in programming.",
#       "cited_paragraph": "A variable is a storage location identified by a name that can hold different types of data, such as integers or strings. The student's answer lacks depth regarding how variables are utilized in programming."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The response correctly identifies where variables can be declared but introduces a minor error with 'label what they are food' instead of 'for.' It shows good understanding but has a slight gap.",
#       "cited_paragraph": "Variables in C++ can be declared at any point before their use, although it is a best practice to declare them at the beginning of a function for clarity and organization. The student's answer is mostly accurate but contains a typographical error."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "B",
#       "reason": "The answer captures the essential difference between the two types of loops, but the explanation could be clearer in terms of how the execution flow differs.",
#       "cited_paragraph": "The 'do...while' loop executes the block of code at least once before checking the condition, whereas the 'while' loop checks the condition before executing. The student’s answer is correct but could benefit from a more straightforward comparison."
#     }
#   ]
# }
# ```
# call_reflection
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer demonstrates a mostly correct understanding of the role of prototypes in addressing high-risk problems and feasibility, but lacks depth in explaining how prototyping contributes to overall problem-solving processes.",
#       "cited_paragraph": "A prototype in problem solving serves to explore ideas and assess feasibility, allowing stakeholders to visualize and refine requirements. While the student mentions addressing high-risk problems, a more comprehensive explanation could include iterative feedback from users or stakeholders."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The response accurately identifies multiple stages affected by testing, including design, production, and coding, showing a thorough understanding of the software development life cycle (SDLC).",
#       "cited_paragraph": "Testing is a critical phase in the SDLC that informs and influences earlier stages like design and coding, as identified in the student's response. It is essential for ensuring the software meets quality standards and functions as intended."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a detailed explanation of the advantages of object-oriented programming, including modularity, reusability, ease of debugging, security, inheritance, and polymorphism, reflecting a nuanced understanding.",
#       "cited_paragraph": "Object-oriented programming promotes modularity and reusability, which facilitate easier maintenance and debugging. The mention of security and the specific benefits of inheritance and polymorphism further demonstrates a comprehensive grasp of the topic."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer correctly identifies that C++ programs start execution at 'int main()', showcasing a clear understanding of program structure.",
#       "cited_paragraph": "In C++, the execution of a program begins at the 'int main()' function, which is the entry point for all C++ programs, indicating a solid comprehension of C++ program structure."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The definition provided is partial, as it describes variables only in terms of data types without explaining their purpose or role in programming.",
#       "cited_paragraph": "A variable is a storage location identified by a name that can hold different types of data, such as integers or strings. The student's answer lacks depth regarding how variables are utilized in programming."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The response correctly identifies where variables can be declared but introduces a minor error with 'label what they are food' instead of 'for.' It shows good understanding but has a slight gap.",
#       "cited_paragraph": "Variables in C++ can be declared at any point before their use, although it is a best practice to declare them at the beginning of a function for clarity and organization. The student's answer is mostly accurate but contains a typographical error."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "B",
#       "reason": "The answer captures the essential difference between the two types of loops, but the explanation could be clearer in terms of how the execution flow differs.",
#       "cited_paragraph": "The 'do...while' loop executes the block of code at least once before checking the condition, whereas the 'while' loop checks the condition before executing. The student’s answer is correct but could benefit from a more straightforward comparison."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# The evaluations provided show a good understanding of the questions asked, but there are some gaps in reasoning for certain scores.
#
# 1. **Question: What is the role of a prototype program in problem solving?**
#    - **Score: B** - This grade seems appropriate given that the evaluator notes a mostly correct understanding but lacks depth. However, the evaluator could have emphasized the importance of rapid iteration and user feedback in the prototyping process, which would have solidified the understanding further.
#
# 2. **Question: What stages in the software life cycle are influenced by the testing stage?**
#    - **Score: A** - This evaluation appears accurate. The response correctly identifies the influence of testing on earlier stages, demonstrating a thorough understanding of the software development life cycle.
#
# 3. **Question: What are the main advantages associated with object-oriented programming?**
#    - **Score: A** - Again, this evaluation is sound, as the response reflects a comprehensive grasp of the advantages of object-oriented programming.
#
# 4. **Question: Where do C++ programs begin to execute?**
#    - **Score: A** - This assessment is also correct. The answer accurately identifies the starting point for C++ program execution.
#
# 5. **Question: What is a variable?**
#    - **Score: C** - The score assigned here may be too lenient, as the evaluator identifies that the explanation is partial. A more fitting score could have been given if the evaluator had emphasized the lack of context regarding the role of variables in programming.
#
# 6. **Question: Where are variables declared in a C++ program?**
#    - **Score: B** - The minor typographical error noted is valid, but it does not significantly detract from the overall understanding presented in the response. The score seems appropriate, but the reasoning could highlight that it does not diminish the overall comprehension of variable declaration.
#
# 7. **Question: What is the main difference between a while and a do...while statement?**
#    - **Score: B** - The reason given is reasonable, as it points out that the distinction is captured but could be clearer. However, the evaluator might have elaborated on specific scenarios or examples where one would be favored over the other to enhance clarity.
#
# Overall, the evaluations are mostly correct, but there are areas where the evaluator could have provided more detailed feedback, particularly in the scoring of the question about variables and the prototype program.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluations provided show a good understanding of the questions asked, but there are some gaps in reasoning for certain scores.
#
# 1. **Question: What is the role of a prototype program in problem solving?**
#    - **Score: B** - This grade seems appropriate given that the evaluator notes a mostly correct understanding but lacks depth. However, the evaluator could have emphasized the importance of rapid iteration and user feedback in the prototyping process, which would have solidified the understanding further.
#
# 2. **Question: What stages in the software life cycle are influenced by the testing stage?**
#    - **Score: A** - This evaluation appears accurate. The response correctly identifies the influence of testing on earlier stages, demonstrating a thorough understanding of the software development life cycle.
#
# 3. **Question: What are the main advantages associated with object-oriented programming?**
#    - **Score: A** - Again, this evaluation is sound, as the response reflects a comprehensive grasp of the advantages of object-oriented programming.
#
# 4. **Question: Where do C++ programs begin to execute?**
#    - **Score: A** - This assessment is also correct. The answer accurately identifies the starting point for C++ program execution.
#
# 5. **Question: What is a variable?**
#    - **Score: C** - The score assigned here may be too lenient, as the evaluator identifies that the explanation is partial. A more fitting score could have been given if the evaluator had emphasized the lack of context regarding the role of variables in programming.
#
# 6. **Question: Where are variables declared in a C++ program?**
#    - **Score: B** - The minor typographical error noted is valid, but it does not significantly detract from the overall understanding presented in the response. The score seems appropriate, but the reasoning could highlight that it does not diminish the overall comprehension of variable declaration.
#
# 7. **Question: What is the main difference between a while and a do...while statement?**
#    - **Score: B** - The reason given is reasonable, as it points out that the distinction is captured but could be clearer. However, the evaluator might have elaborated on specific scenarios or examples where one would be favored over the other to enhance clarity.
#
# Overall, the evaluations are mostly correct, but there are areas where the evaluator could have provided more detailed feedback, particularly in the scoring of the question about variables and the prototype program.
# ================================== Ai Message ==================================
#
# The evaluation provided demonstrates a generally good understanding of the responses, but there are specific gaps in reasoning that affect the accuracy of the assigned grades.
#
# 1. The score of **B** for the prototype program question is justified but would benefit from a more detailed explanation of key concepts like rapid iteration and user feedback, which are crucial aspects of prototyping.
#
# 2. The scores of **A** for the software life cycle, object-oriented programming, and C++ execution questions are accurately assigned, reflecting a thorough understanding.
#
# 3. The score of **C** for the variable question might indeed be lenient, as a more critical assessment could highlight the lack of comprehensive context regarding variables.
#
# 4. The score of **B** for the variable declaration question is appropriate, but the evaluator should emphasize that minor errors do not significantly hinder overall comprehension.
#
# 5. The score of **B** for the while vs. do...while statement question is reasonable; however, providing examples would strengthen the evaluation and clarify the distinction.
#
# Overall, while the evaluations are mostly correct, there is room for improvement in providing detailed feedback and justifications, particularly in certain areas.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation provided demonstrates a generally good understanding of the responses, but there are specific gaps in reasoning that affect the accuracy of the assigned grades.
#
# 1. The score of **B** for the prototype program question is justified but would benefit from a more detailed explanation of key concepts like rapid iteration and user feedback, which are crucial aspects of prototyping.
#
# 2. The scores of **A** for the software life cycle, object-oriented programming, and C++ execution questions are accurately assigned, reflecting a thorough understanding.
#
# 3. The score of **C** for the variable question might indeed be lenient, as a more critical assessment could highlight the lack of comprehensive context regarding variables.
#
# 4. The score of **B** for the variable declaration question is appropriate, but the evaluator should emphasize that minor errors do not significantly hinder overall comprehension.
#
# 5. The score of **B** for the while vs. do...while statement question is reasonable; however, providing examples would strengthen the evaluation and clarify the distinction.
#
# Overall, while the evaluations are mostly correct, there is room for improvement in providing detailed feedback and justifications, particularly in certain areas.
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a generally sound understanding, but there are some gaps that could be addressed for greater accuracy.
#
# 1. The score of **B** for the prototype program question is noted as justified, but the evaluator could have elaborated more on the importance of rapid iteration and user feedback in prototyping, which are key elements in the process.
#
# 2. The assigned scores of **A** for the software life cycle, object-oriented programming, and C++ execution questions are correctly noted as reflecting a thorough understanding, suggesting that the evaluator has a good grasp of these concepts.
#
# 3. The **C** score for the variable question is critiqued as potentially lenient, indicating that a deeper analysis might be warranted to uncover any significant gaps in understanding.
#
# 4. The **B** score for the variable declaration question is deemed appropriate, yet the evaluator could have pointed out that minor errors do not majorly impact the overall comprehension, which would provide more clarity.
#
# 5. The **B** score for the while vs. do...while statement question is seen as reasonable, but the suggestion to include examples to clarify the distinction is a valid point that could enhance the evaluation.
#
# In summary, while the evaluations are mostly accurate, the evaluator could improve their assessments by providing more detailed feedback and justifications, particularly in areas where key concepts could be better articulated.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a generally sound understanding, but there are some gaps that could be addressed for greater accuracy.
#
# 1. The score of **B** for the prototype program question is noted as justified, but the evaluator could have elaborated more on the importance of rapid iteration and user feedback in prototyping, which are key elements in the process.
#
# 2. The assigned scores of **A** for the software life cycle, object-oriented programming, and C++ execution questions are correctly noted as reflecting a thorough understanding, suggesting that the evaluator has a good grasp of these concepts.
#
# 3. The **C** score for the variable question is critiqued as potentially lenient, indicating that a deeper analysis might be warranted to uncover any significant gaps in understanding.
#
# 4. The **B** score for the variable declaration question is deemed appropriate, yet the evaluator could have pointed out that minor errors do not majorly impact the overall comprehension, which would provide more clarity.
#
# 5. The **B** score for the while vs. do...while statement question is seen as reasonable, but the suggestion to include examples to clarify the distinction is a valid point that could enhance the evaluation.
#
# In summary, while the evaluations are mostly accurate, the evaluator could improve their assessments by providing more detailed feedback and justifications, particularly in areas where key concepts could be better articulated.
# ================================== Ai Message ==================================
#
# The evaluation you provided demonstrates a generally sound understanding, but there are some gaps that could be addressed for greater accuracy.
#
# 1. The score of **B** for the prototype program question is noted as justified, but the evaluator could have elaborated more on the importance of rapid iteration and user feedback in prototyping, which are key elements in the process.
#
# 2. The assigned scores of **A** for the software life cycle, object-oriented programming, and C++ execution questions are correctly noted as reflecting a thorough understanding, suggesting that the evaluator has a good grasp of these concepts.
#
# 3. The **C** score for the variable question is critiqued as potentially lenient, indicating that a deeper analysis might be warranted to uncover any significant gaps in understanding.
#
# 4. The **B** score for the variable declaration question is deemed appropriate, yet the evaluator could have pointed out that minor errors do not majorly impact the overall comprehension, which would provide more clarity.
#
# 5. The **B** score for the while vs. do...while statement question is seen as reasonable, but the suggestion to include examples to clarify the distinction is a valid point that could enhance the evaluation.
#
# In summary, while the evaluations are mostly accurate, the evaluator could improve their assessments by providing more detailed feedback and justifications, particularly in areas where key concepts could be better articulated.
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "C",
#       "reason": "The answer reflects partial understanding of prototyping but lacks depth regarding its role in problem solving.",
#       "cited_paragraph": "A prototype program is typically used to simulate and test the functionality of a system and is crucial in understanding user requirements, therefore aiding in problem solving."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "C",
#       "reason": "The student identifies some relevant stages but does not fully encompass the breadth of the software development life cycle (SDLC) impacted by testing.",
#       "cited_paragraph": "The testing stage influences multiple stages of the SDLC, including requirements, design, coding, and maintenance, as it helps identify defects and verify that the product meets the specified requirements."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "B",
#       "reason": "The answer correctly identifies two key advantages, but lacks mention of other significant benefits like encapsulation and polymorphism.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several advantages, including reusability, ease of maintenance, encapsulation, and polymorphism, all contributing to more efficient software development."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer is concise and accurately identifies the starting point of C++ program execution.",
#       "cited_paragraph": "In C++, programs begin execution at the 'main' function, which serves as the entry point for all C++ applications."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The answer provides a correct definition but could elaborate on the types of data and examples of variable usage.",
#       "cited_paragraph": "A variable is a storage location in memory that holds data which can vary during program execution. It has a specific type, such as int, float, or string."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student’s answer is mostly correct but could benefit from clarity regarding scope and initialization.",
#       "cited_paragraph": "In C++, variables can be declared globally, making them accessible throughout the program, or locally within functions or blocks, which limits their scope to the containing function."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The answer demonstrates a thorough understanding of the differences between the two loop constructs.",
#       "cited_paragraph": "The key difference is that a 'while' loop checks the condition before executing the loop body, potentially resulting in zero executions, whereas a 'do...while' loop guarantees at least one execution of the loop body before checking the condition."
#     }
#   ]
# }
# ```
# call_reflection
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "C",
#       "reason": "The answer reflects partial understanding of prototyping but lacks depth regarding its role in problem solving.",
#       "cited_paragraph": "A prototype program is typically used to simulate and test the functionality of a system and is crucial in understanding user requirements, therefore aiding in problem solving."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "C",
#       "reason": "The student identifies some relevant stages but does not fully encompass the breadth of the software development life cycle (SDLC) impacted by testing.",
#       "cited_paragraph": "The testing stage influences multiple stages of the SDLC, including requirements, design, coding, and maintenance, as it helps identify defects and verify that the product meets the specified requirements."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "B",
#       "reason": "The answer correctly identifies two key advantages, but lacks mention of other significant benefits like encapsulation and polymorphism.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several advantages, including reusability, ease of maintenance, encapsulation, and polymorphism, all contributing to more efficient software development."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer is concise and accurately identifies the starting point of C++ program execution.",
#       "cited_paragraph": "In C++, programs begin execution at the 'main' function, which serves as the entry point for all C++ applications."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The answer provides a correct definition but could elaborate on the types of data and examples of variable usage.",
#       "cited_paragraph": "A variable is a storage location in memory that holds data which can vary during program execution. It has a specific type, such as int, float, or string."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student’s answer is mostly correct but could benefit from clarity regarding scope and initialization.",
#       "cited_paragraph": "In C++, variables can be declared globally, making them accessible throughout the program, or locally within functions or blocks, which limits their scope to the containing function."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The answer demonstrates a thorough understanding of the differences between the two loop constructs.",
#       "cited_paragraph": "The key difference is that a 'while' loop checks the condition before executing the loop body, potentially resulting in zero executions, whereas a 'do...while' loop guarantees at least one execution of the loop body before checking the condition."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# The evaluation provided has some inconsistencies and gaps in understanding regarding the assigned scores:
#
# 1. **Prototyping (Score: C)**: The evaluator mentions that the answer reflects a partial understanding and lacks depth. However, the cited paragraph indicates a clear explanation of a prototype's role in understanding user requirements, which is a significant aspect of problem-solving. This suggests that a score of B would be more appropriate since the answer does demonstrate a reasonable understanding.
#
# 2. **Testing Stage in SDLC (Score: C)**: Similar to the first question, the evaluator notes that the student identifies some relevant stages but does not encompass the breadth of SDLC. However, the cited paragraph mentions multiple stages (requirements, design, coding, maintenance) influenced by testing, showing a better understanding than a C score implies. A score of B could be justified here as well.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator mentions that the answer lacks mention of encapsulation and polymorphism. However, the cited paragraph does include encapsulation and polymorphism as advantages, indicating that the answer is more comprehensive. Thus, a score of A could be more fitting given the thoroughness of the response.
#
# 4. **Variable Definition (Score: B)**: The evaluator accurately identifies that the definition could be expanded, but the fundamental understanding is correct. A score of B seems appropriate here, aligning with the evaluator's reasoning.
#
# 5. **Variable Declaration in C++ (Score: B)**: While the evaluator notes that clarity regarding scope could be improved, the overall explanation is solid. A B score is appropriate, but if the scope and initialization were better addressed, an A could be justified.
#
# 6. **While vs. Do...While (Score: A)**: The evaluator correctly assigns an A for this question as the answer demonstrates a thorough understanding.
#
# In conclusion, while the evaluator's reasoning is generally sound, there are notable gaps in understanding the depth of the responses for the first two questions. An adjustment of grades for those questions to B would provide a more accurate reflection of the understanding demonstrated.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation provided has some inconsistencies and gaps in understanding regarding the assigned scores:
#
# 1. **Prototyping (Score: C)**: The evaluator mentions that the answer reflects a partial understanding and lacks depth. However, the cited paragraph indicates a clear explanation of a prototype's role in understanding user requirements, which is a significant aspect of problem-solving. This suggests that a score of B would be more appropriate since the answer does demonstrate a reasonable understanding.
#
# 2. **Testing Stage in SDLC (Score: C)**: Similar to the first question, the evaluator notes that the student identifies some relevant stages but does not encompass the breadth of SDLC. However, the cited paragraph mentions multiple stages (requirements, design, coding, maintenance) influenced by testing, showing a better understanding than a C score implies. A score of B could be justified here as well.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator mentions that the answer lacks mention of encapsulation and polymorphism. However, the cited paragraph does include encapsulation and polymorphism as advantages, indicating that the answer is more comprehensive. Thus, a score of A could be more fitting given the thoroughness of the response.
#
# 4. **Variable Definition (Score: B)**: The evaluator accurately identifies that the definition could be expanded, but the fundamental understanding is correct. A score of B seems appropriate here, aligning with the evaluator's reasoning.
#
# 5. **Variable Declaration in C++ (Score: B)**: While the evaluator notes that clarity regarding scope could be improved, the overall explanation is solid. A B score is appropriate, but if the scope and initialization were better addressed, an A could be justified.
#
# 6. **While vs. Do...While (Score: A)**: The evaluator correctly assigns an A for this question as the answer demonstrates a thorough understanding.
#
# In conclusion, while the evaluator's reasoning is generally sound, there are notable gaps in understanding the depth of the responses for the first two questions. An adjustment of grades for those questions to B would provide a more accurate reflection of the understanding demonstrated.
# ================================== Ai Message ==================================
#
# The evaluation provided demonstrates a thoughtful analysis, but there are several gaps in the understanding of the evaluator regarding the assigned scores:
#
# 1. **Prototyping (Score: C)**: The evaluator's reasoning suggests a lack of recognition for the clarity and relevance of the explanation provided. Given that the response outlines the role of prototypes in understanding user requirements, a higher score would indeed be more appropriate.
#
# 2. **Testing Stage in SDLC (Score: C)**: The evaluator's assessment appears to overlook the multiple stages mentioned in the response, indicating a better grasp of the subject than a C score suggests. Adjusting the score to B would reflect this understanding more accurately.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator has misinterpreted the content by claiming that encapsulation and polymorphism were not mentioned, despite their inclusion in the response. This indicates a thorough understanding that might warrant an A score.
#
# 4. **Variable Definition (Score: B)**: The evaluator's reasoning aligns well with the score assigned, and no significant gaps are present in this assessment.
#
# 5. **Variable Declaration in C++ (Score: B)**: Similar to the previous point, the evaluator's reasoning supports the assigned score, recognizing that while there are areas for improvement, the overall understanding is solid.
#
# 6. **While vs. Do...While (Score: A)**: This assessment is correctly noted as an A, reflecting the thorough understanding demonstrated.
#
# In summary, while the evaluator's overall approach is commendable, there are significant gaps in the scores for the first two questions that warrant reconsideration. Adjusting those grades to B would provide a more accurate representation of the understanding demonstrated in the responses.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation provided demonstrates a thoughtful analysis, but there are several gaps in the understanding of the evaluator regarding the assigned scores:
#
# 1. **Prototyping (Score: C)**: The evaluator's reasoning suggests a lack of recognition for the clarity and relevance of the explanation provided. Given that the response outlines the role of prototypes in understanding user requirements, a higher score would indeed be more appropriate.
#
# 2. **Testing Stage in SDLC (Score: C)**: The evaluator's assessment appears to overlook the multiple stages mentioned in the response, indicating a better grasp of the subject than a C score suggests. Adjusting the score to B would reflect this understanding more accurately.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator has misinterpreted the content by claiming that encapsulation and polymorphism were not mentioned, despite their inclusion in the response. This indicates a thorough understanding that might warrant an A score.
#
# 4. **Variable Definition (Score: B)**: The evaluator's reasoning aligns well with the score assigned, and no significant gaps are present in this assessment.
#
# 5. **Variable Declaration in C++ (Score: B)**: Similar to the previous point, the evaluator's reasoning supports the assigned score, recognizing that while there are areas for improvement, the overall understanding is solid.
#
# 6. **While vs. Do...While (Score: A)**: This assessment is correctly noted as an A, reflecting the thorough understanding demonstrated.
#
# In summary, while the evaluator's overall approach is commendable, there are significant gaps in the scores for the first two questions that warrant reconsideration. Adjusting those grades to B would provide a more accurate representation of the understanding demonstrated in the responses.
# ================================== Ai Message ==================================
#
# The evaluation appears to contain several inaccuracies regarding the assigned scores. Here’s a breakdown:
#
# 1. **Prototyping (Score: C)**: The evaluator fails to recognize the depth of the explanation, which warrants a higher score. Acknowledging the role of prototypes in user requirements should lead to at least a B score.
#
# 2. **Testing Stage in SDLC (Score: C)**: The evaluator underestimates the complexity of the response. Given the mention of multiple stages, a B score would be more fitting.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator misinterprets the content by stating that encapsulation and polymorphism were not addressed. This oversight suggests a more profound misunderstanding, with an A score being more appropriate for the detailed explanation provided.
#
# 4. **Variable Definition (Score: B)**: The evaluator's reasoning is sound, and the assigned grade is justified.
#
# 5. **Variable Declaration in C++ (Score: B)**: Similar to the previous point, the evaluator's reasoning holds, and the score is appropriate.
#
# 6. **While vs. Do...While (Score: A)**: This score accurately reflects the understanding demonstrated.
#
# Overall, the evaluator's scores for the first two questions should be adjusted to better reflect the responses' quality. A B score for both would provide a more accurate assessment.
#
# In summary, the evaluation shows a commendable effort but requires adjustments in certain areas to align the scores with the demonstrated understanding in the content.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation appears to contain several inaccuracies regarding the assigned scores. Here’s a breakdown:
#
# 1. **Prototyping (Score: C)**: The evaluator fails to recognize the depth of the explanation, which warrants a higher score. Acknowledging the role of prototypes in user requirements should lead to at least a B score.
#
# 2. **Testing Stage in SDLC (Score: C)**: The evaluator underestimates the complexity of the response. Given the mention of multiple stages, a B score would be more fitting.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator misinterprets the content by stating that encapsulation and polymorphism were not addressed. This oversight suggests a more profound misunderstanding, with an A score being more appropriate for the detailed explanation provided.
#
# 4. **Variable Definition (Score: B)**: The evaluator's reasoning is sound, and the assigned grade is justified.
#
# 5. **Variable Declaration in C++ (Score: B)**: Similar to the previous point, the evaluator's reasoning holds, and the score is appropriate.
#
# 6. **While vs. Do...While (Score: A)**: This score accurately reflects the understanding demonstrated.
#
# Overall, the evaluator's scores for the first two questions should be adjusted to better reflect the responses' quality. A B score for both would provide a more accurate assessment.
#
# In summary, the evaluation shows a commendable effort but requires adjustments in certain areas to align the scores with the demonstrated understanding in the content.
# ================================== Ai Message ==================================
#
# The evaluation appears to contain several inaccuracies regarding the assigned scores. Here’s a breakdown:
#
# 1. **Prototyping (Score: C)**: The evaluator fails to recognize the depth of the explanation, which warrants a higher score. Acknowledging the role of prototypes in user requirements should lead to at least a B score.
#
# 2. **Testing Stage in SDLC (Score: C)**: The evaluator underestimates the complexity of the response. Given the mention of multiple stages, a B score would be more fitting.
#
# 3. **Object-Oriented Programming (Score: B)**: The evaluator misinterprets the content by stating that encapsulation and polymorphism were not addressed. This oversight suggests a more profound misunderstanding, with an A score being more appropriate for the detailed explanation provided.
#
# 4. **Variable Definition (Score: B)**: The evaluator's reasoning is sound, and the assigned grade is justified.
#
# 5. **Variable Declaration in C++ (Score: B)**: Similar to the previous point, the evaluator's reasoning holds, and the score is appropriate.
#
# 6. **While vs. Do...While (Score: A)**: This score accurately reflects the understanding demonstrated.
#
# Overall, the evaluator's scores for the first two questions should be adjusted to better reflect the responses' quality. A B score for both would provide a more accurate assessment.
#
# In summary, the evaluation shows a commendable effort but requires adjustments in certain areas to align the scores with the demonstrated understanding in the content.
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer reflects a good understanding of prototyping; however, it lacks details on how it aids problem-solving specifically.",
#       "cited_paragraph": "A prototype program helps in visualizing how a software product will function, allowing for early identification of potential problems and requirements. While the student correctly identifies the basic purpose of a prototype, they could enhance their answer by discussing its role in iterative development and user feedback."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "B",
#       "reason": "The answer identifies relevant stages but could benefit from a more comprehensive explanation of how testing impacts these phases.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) is crucial as it influences the Elaboration, Construction, and Transition phases by ensuring that each phase meets the required specifications and functions correctly. The student recognizes the phases but should elaborate on the importance of testing within these contexts."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a thorough and nuanced understanding of the advantages of OOP, clearly explaining encapsulation, inheritance, and polymorphism.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers significant advantages such as encapsulation, which hides implementation details; inheritance, which promotes code reusability; and polymorphism, which allows for dynamic method resolution. The student accurately describes these concepts, showing a strong grasp of their implications in software development."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "B",
#       "reason": "The response correctly identifies the starting point of C++ execution but could briefly mention the significance of the 'main' function.",
#       "cited_paragraph": "In C++, program execution begins at the 'main()' function, which is essential as it serves as the entry point for the program. The student's answer is mostly correct but would be more complete with a mention of the role of 'main()' in the execution flow."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The explanation of a variable is mostly correct but could include more context about its use in programming.",
#       "cited_paragraph": "A variable is a storage location in memory characterized by a name and a data type, allowing programs to store and manipulate data. The answer is fundamentally correct but could be improved by discussing variable scope, lifetime, or examples of variable usage in programming."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student correctly identifies the typical declaration location but lacks detail on the implications of variable scope.",
#       "cited_paragraph": "Variables in C++ are generally declared at the beginning of a function or block, which is important for defining their scope and lifetime. The answer is mostly accurate but could be enhanced by discussing how scope affects variable accessibility within different parts of the program."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "B",
#       "reason": "The answer captures the essence of the difference, but could elaborate on practical implications or examples.",
#       "cited_paragraph": "The main difference between a while and a do...while statement is that a do...while loop guarantees that the block of code will execute at least once, irrespective of the condition being true. While the student provides a correct distinction, they could strengthen their answer by including examples of when to use each type of loop."
#     }
#   ]
# }
# ```
# call_reflection
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The answer reflects a good understanding of prototyping; however, it lacks details on how it aids problem-solving specifically.",
#       "cited_paragraph": "A prototype program helps in visualizing how a software product will function, allowing for early identification of potential problems and requirements. While the student correctly identifies the basic purpose of a prototype, they could enhance their answer by discussing its role in iterative development and user feedback."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "B",
#       "reason": "The answer identifies relevant stages but could benefit from a more comprehensive explanation of how testing impacts these phases.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) is crucial as it influences the Elaboration, Construction, and Transition phases by ensuring that each phase meets the required specifications and functions correctly. The student recognizes the phases but should elaborate on the importance of testing within these contexts."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a thorough and nuanced understanding of the advantages of OOP, clearly explaining encapsulation, inheritance, and polymorphism.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers significant advantages such as encapsulation, which hides implementation details; inheritance, which promotes code reusability; and polymorphism, which allows for dynamic method resolution. The student accurately describes these concepts, showing a strong grasp of their implications in software development."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "B",
#       "reason": "The response correctly identifies the starting point of C++ execution but could briefly mention the significance of the 'main' function.",
#       "cited_paragraph": "In C++, program execution begins at the 'main()' function, which is essential as it serves as the entry point for the program. The student's answer is mostly correct but would be more complete with a mention of the role of 'main()' in the execution flow."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The explanation of a variable is mostly correct but could include more context about its use in programming.",
# ...
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "F",
#       "reason": "The answer is fundamentally incorrect as it does not provide any relevant information.",
#       "cited_paragraph": "The main advantages of object-oriented programming (OOP) include encapsulation, inheritance, polymorphism, and reusability, allowing for more modular, maintainable, and scalable code."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "F",
#       "reason": "The answer is fundamentally incorrect as it does not provide any relevant information.",
#       "cited_paragraph": "C++ programs begin execution from the 'main' function, specifically the 'int main()' function which serves as the entry point of a program."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "F",
#       "reason": "The answer is fundamentally incorrect as it does not provide any relevant information.",
#       "cited_paragraph": "A variable is a storage location identified by a name that can hold data which may change during program execution. It is fundamental to programming as it allows the storage and manipulation of data."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "F",
#       "reason": "The answer is fundamentally incorrect as it does not provide any relevant information.",
#       "cited_paragraph": "Variables in a C++ program can be declared within function bodies, at the global level, or within classes, depending on the scope and lifetime required for the variable."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "F",
#       "reason": "The answer is fundamentally incorrect as it does not provide any relevant information.",
#       "cited_paragraph": "The main difference between a while statement and a do...while statement is that the while statement checks the condition before executing the loop, whereas the do...while statement executes the loop body at least once before checking the condition."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# The evaluations given for all the questions have been assigned a grade of "F," indicating a fundamentally incorrect understanding. However, upon reviewing the provided cited paragraphs, it is evident that these answers contain accurate and relevant information regarding each topic.
#
# 1. **Prototyping in Problem Solving:** The explanation correctly identifies the role of a prototype program in visualizing and testing concepts in problem solving, which is a valid point.
#
# 2. **Testing Stage Influence:** The cited paragraph accurately describes how the testing stage can influence various stages of the software development life cycle, which is a critical aspect of software development.
#
# 3. **Advantages of Object-Oriented Programming:** The listed advantages of OOP (encapsulation, inheritance, polymorphism, and reusability) are indeed the main benefits associated with this programming paradigm.
#
# 4. **C++ Program Execution:** The explanation of where C++ programs begin execution from the 'main' function is correct and fundamental knowledge in programming.
#
# 5. **Definition of a Variable:** The description of a variable as a storage location that can hold data is accurate and fundamental to programming concepts.
#
# 6. **Variable Declaration in C++:** The information regarding where variables can be declared within function bodies, globally, or within classes is also correct.
#
# 7. **While vs. Do...While Statements:** The explanation of the difference between these two types of loops is accurate and clearly outlines the operational differences.
#
# Given that each cited paragraph contains accurate and relevant information, the evaluator's assigned scores of "F" reflect a misunderstanding of the answers provided. Therefore, the evaluations lack coherence and accuracy as they fail to recognize the correctness of the explanations.
#
# Overall, the grades assigned do not align with the quality of the responses, which merits a reassessment of the evaluations.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluations given for all the questions have been assigned a grade of "F," indicating a fundamentally incorrect understanding. However, upon reviewing the provided cited paragraphs, it is evident that these answers contain accurate and relevant information regarding each topic.
#
# 1. **Prototyping in Problem Solving:** The explanation correctly identifies the role of a prototype program in visualizing and testing concepts in problem solving, which is a valid point.
#
# 2. **Testing Stage Influence:** The cited paragraph accurately describes how the testing stage can influence various stages of the software development life cycle, which is a critical aspect of software development.
#
# 3. **Advantages of Object-Oriented Programming:** The listed advantages of OOP (encapsulation, inheritance, polymorphism, and reusability) are indeed the main benefits associated with this programming paradigm.
#
# 4. **C++ Program Execution:** The explanation of where C++ programs begin execution from the 'main' function is correct and fundamental knowledge in programming.
#
# 5. **Definition of a Variable:** The description of a variable as a storage location that can hold data is accurate and fundamental to programming concepts.
#
# 6. **Variable Declaration in C++:** The information regarding where variables can be declared within function bodies, globally, or within classes is also correct.
#
# 7. **While vs. Do...While Statements:** The explanation of the difference between these two types of loops is accurate and clearly outlines the operational differences.
#
# Given that each cited paragraph contains accurate and relevant information, the evaluator's assigned scores of "F" reflect a misunderstanding of the answers provided. Therefore, the evaluations lack coherence and accuracy as they fail to recognize the correctness of the explanations.
#
# Overall, the grades assigned do not align with the quality of the responses, which merits a reassessment of the evaluations.
# ================================== Ai Message ==================================
#
# The evaluator's assessment of all responses as "F" is fundamentally incorrect. Each explanation provided for the questions demonstrates accurate understanding and relevant information, which contradicts the assigned grade.
#
# 1. **Prototyping in Problem Solving:** The evaluator correctly notes that the explanation identifies the role of prototypes in problem solving, indicating a valid understanding of the concept.
#
# 2. **Testing Stage Influence:** The description of how the testing stage influences the software development life cycle is accurately captured, showcasing an essential aspect of the process.
#
# 3. **Advantages of Object-Oriented Programming:** The evaluator acknowledges that the advantages listed (encapsulation, inheritance, polymorphism, and reusability) are indeed fundamental benefits of OOP, which shows comprehension of the topic.
#
# 4. **C++ Program Execution:** The explanation regarding the execution of C++ programs starting from the 'main' function is fundamental knowledge and is accurately stated.
#
# 5. **Definition of a Variable:** The evaluator correctly identifies the description of a variable as a storage location that can hold data, reflecting a basic understanding of programming concepts.
#
# 6. **Variable Declaration in C++:** The information on variable declaration is also accurately represented, highlighting the correct scope of variable declaration.
#
# 7. **While vs. Do...While Statements:** The evaluator recognizes the accurate explanation of the differences between these two looping structures, indicating a clear understanding.
#
# Overall, the evaluations lack coherence and accuracy, as the assigned "F" grades do not align with the quality and correctness of the responses. A reassessment of the evaluations is warranted.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluator's assessment of all responses as "F" is fundamentally incorrect. Each explanation provided for the questions demonstrates accurate understanding and relevant information, which contradicts the assigned grade.
#
# 1. **Prototyping in Problem Solving:** The evaluator correctly notes that the explanation identifies the role of prototypes in problem solving, indicating a valid understanding of the concept.
#
# 2. **Testing Stage Influence:** The description of how the testing stage influences the software development life cycle is accurately captured, showcasing an essential aspect of the process.
#
# 3. **Advantages of Object-Oriented Programming:** The evaluator acknowledges that the advantages listed (encapsulation, inheritance, polymorphism, and reusability) are indeed fundamental benefits of OOP, which shows comprehension of the topic.
#
# 4. **C++ Program Execution:** The explanation regarding the execution of C++ programs starting from the 'main' function is fundamental knowledge and is accurately stated.
#
# 5. **Definition of a Variable:** The evaluator correctly identifies the description of a variable as a storage location that can hold data, reflecting a basic understanding of programming concepts.
#
# 6. **Variable Declaration in C++:** The information on variable declaration is also accurately represented, highlighting the correct scope of variable declaration.
#
# 7. **While vs. Do...While Statements:** The evaluator recognizes the accurate explanation of the differences between these two looping structures, indicating a clear understanding.
#
# Overall, the evaluations lack coherence and accuracy, as the assigned "F" grades do not align with the quality and correctness of the responses. A reassessment of the evaluations is warranted.
# ================================== Ai Message ==================================
#
# The evaluation of the responses is fundamentally flawed. The consistent assignment of "F" grades across all questions does not reflect the understanding demonstrated in the explanations. Each response shows a clear grasp of the topics discussed, which contradicts the evaluator's harsh grading.
#
# 1. **Prototyping in Problem Solving:** The evaluator's assessment acknowledges the role of prototypes, indicating a solid understanding of their importance in the problem-solving process.
#
# 2. **Testing Stage Influence:** The explanation regarding the testing stage's impact on the software development life cycle is accurately described, demonstrating a good comprehension of this critical phase.
#
# 3. **Advantages of Object-Oriented Programming:** The evaluator correctly notes that encapsulation, inheritance, polymorphism, and reusability are key advantages of OOP, highlighting an accurate understanding of the benefits provided by this programming paradigm.
#
# 4. **C++ Program Execution:** The explanation about the execution of C++ programs from the 'main' function is a fundamental concept in programming and is correctly articulated.
#
# 5. **Definition of a Variable:** The description of a variable as a storage location for data is accurate and reflects a basic understanding of programming principles.
#
# 6. **Variable Declaration in C++:** The explanation of variable declaration in C++ is also correctly presented, showing an understanding of its scope and significance.
#
# 7. **While vs. Do...While Statements:** The distinctions made between these two looping structures are correctly identified, indicating a clear and accurate understanding of control flow in programming.
#
# Overall, the evaluator's grades do not align with the quality of the explanations provided, which are accurate and demonstrate a strong understanding of the concepts. A reassessment is necessary to reflect this understanding appropriately.
# call_reflection
# ================================== Ai Message ==================================
#
# The evaluation of the responses is fundamentally flawed. The consistent assignment of "F" grades across all questions does not reflect the understanding demonstrated in the explanations. Each response shows a clear grasp of the topics discussed, which contradicts the evaluator's harsh grading.
#
# 1. **Prototyping in Problem Solving:** The evaluator's assessment acknowledges the role of prototypes, indicating a solid understanding of their importance in the problem-solving process.
#
# 2. **Testing Stage Influence:** The explanation regarding the testing stage's impact on the software development life cycle is accurately described, demonstrating a good comprehension of this critical phase.
#
# 3. **Advantages of Object-Oriented Programming:** The evaluator correctly notes that encapsulation, inheritance, polymorphism, and reusability are key advantages of OOP, highlighting an accurate understanding of the benefits provided by this programming paradigm.
#
# 4. **C++ Program Execution:** The explanation about the execution of C++ programs from the 'main' function is a fundamental concept in programming and is correctly articulated.
#
# 5. **Definition of a Variable:** The description of a variable as a storage location for data is accurate and reflects a basic understanding of programming principles.
#
# 6. **Variable Declaration in C++:** The explanation of variable declaration in C++ is also correctly presented, showing an understanding of its scope and significance.
#
# 7. **While vs. Do...While Statements:** The distinctions made between these two looping structures are correctly identified, indicating a clear and accurate understanding of control flow in programming.
#
# Overall, the evaluator's grades do not align with the quality of the explanations provided, which are accurate and demonstrate a strong understanding of the concepts. A reassessment is necessary to reflect this understanding appropriately.
# ================================== Ai Message ==================================
#
# The evaluation of the responses is fundamentally flawed. The consistent assignment of "F" grades across all questions does not reflect the understanding demonstrated in the explanations. Each response shows a clear grasp of the topics discussed, which contradicts the evaluator's harsh grading.
#
# 1. **Prototyping in Problem Solving:** The evaluator's assessment acknowledges the role of prototypes, indicating a solid understanding of their importance in the problem-solving process.
#
# 2. **Testing Stage Influence:** The explanation regarding the testing stage's impact on the software development life cycle is accurately described, demonstrating a good comprehension of this critical phase.
#
# 3. **Advantages of Object-Oriented Programming:** The evaluator correctly notes that encapsulation, inheritance, polymorphism, and reusability are key advantages of OOP, highlighting an accurate understanding of the benefits provided by this programming paradigm.
#
# 4. **C++ Program Execution:** The explanation about the execution of C++ programs from the 'main' function is a fundamental concept in programming and is correctly articulated.
#
# 5. **Definition of a Variable:** The description of a variable as a storage location for data is accurate and reflects a basic understanding of programming principles.
#
# 6. **Variable Declaration in C++:** The explanation of variable declaration in C++ is also correctly presented, showing an understanding of its scope and significance.
#
# 7. **While vs. Do...While Statements:** The distinctions made between these two looping structures are correctly identified, indicating a clear and accurate understanding of control flow in programming.
#
# Overall, the evaluator's grades do not align with the quality of the explanations provided, which are accurate and demonstrate a strong understanding of the concepts. A reassessment is necessary to reflect this understanding appropriately.

# %%
from agent.graphs import *
graph_rag_final_responses = {}
graph = basic_rag_graph()

for student_id in benchmark_lesson_1.keys():    
    exec_state = OverallState(
         user_input = {"open_questions": benchmark_lesson_1[student_id]},
    concepts_to_evaluate=json.dumps(unique_list_of_concepts),
    blooms_state="understand",
    lesson_doc = lesson_1_doc,
    messages=[]
    )
    try:
        grade_dict = execute_graph(exec_state, graph)
    except Exception as e:
            grade_dict = {"ERROR": e}
    graph_rag_final_responses[student_id] = grade_dict

save_json(graph_rag_final_responses, 'data/graph_rag_final_responses.json')
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_i0ed2dlPPjiZLCUI3AephoOf)
#  Call ID: call_i0ed2dlPPjiZLCUI3AephoOf
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_PHDcgjGI1205aEFVzUCYNDBf)
#  Call ID: call_PHDcgjGI1205aEFVzUCYNDBf
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_rJFtQxTUVl0MfcMLCzNUm4L7)
#  Call ID: call_rJFtQxTUVl0MfcMLCzNUm4L7
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_SIerQH5IUptK0eLU65WWpF9T)
#  Call ID: call_SIerQH5IUptK0eLU65WWpF9T
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_42NjyUzj9xzKqImL8pRy6Kfi)
#  Call ID: call_42NjyUzj9xzKqImL8pRy6Kfi
#   Args:
#     question: What is a variable?
#   query_lesson (call_j6MJJkqRY5sHN96Zbe5sEA3z)
#  Call ID: call_j6MJJkqRY5sHN96Zbe5sEA3z
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_3rrfb2dIrBee5i1vBmAMuErY)
#  Call ID: call_3rrfb2dIrBee5i1vBmAMuErY
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `main()` function. This is the starting point for any C++ program, and all execution flows from this function.
# The answer: A variable is a storage location in a program that holds data and has a name associated with it. This allows programmers to store, modify, and retrieve values throughout the code. For example, in C++, a variable can be defined to store an integer count of items or a string representing an item's name. By using meaningful names for variables, programmers can make their code more readable and easier to maintain.
# The answer: In a C++ program, variables can be declared anywhere within the scope of a function or block. However, a good practice—especially for beginners—is to declare them near the start of the function or block where they will be used. This approach helps make the code clearer and more organized, allowing for easier understanding and maintenance as the program grows in complexity.
# The answer: The testing stage in the Software Development Life Cycle (SDLC) influences several key stages, including:
#
# 1. **Requirements Gathering**: Testing helps clarify requirements by identifying ambiguities or inconsistencies in what needs to be built, ensuring that the final product meets user expectations.
#
# 2. **Design**: The design stage may be adjusted based on test cases and scenarios developed during testing to ensure that the architecture and components are testable and will meet the requirements.
#
# 3. **Implementation**: During coding, developers may write code with testing in mind, implementing features that facilitate testing (e.g., modular design, clear interfaces).
#
# 4. **Maintenance**: After deployment, testing reveals bugs or issues that need to be fixed, guiding maintenance efforts and updates to the software.
#
# 5. **Deployment**: Before deployment, software often undergoes testing to ensure it is stable and functional, influencing the decision to release it to users.
#
# In summary, testing is integral to refining requirements, guiding design and implementation, ensuring quality during deployment, and informing maintenance practices, ultimately contributing to a more reliable software product.
# The answer: The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked:
#
# - **While Loop**: The condition is checked at the beginning of the loop. If the condition is false from the start, the loop's body may not execute at all.
#
#     Example:
#     ```cpp
#     while (condition) {
#         // loop body
#     }
#     ```
#
# - **Do...While Loop**: The loop's body is executed at least once before the condition is checked at the end. This guarantees that the code inside the loop runs at least one time, regardless of whether the condition is true or false initially.
#
#     Example:
#     ```cpp
#     do {
#         // loop body
#     } while (condition);
#     ```
#
# This difference is important when you want to ensure that the loop's body executes at least once, such as when prompting a user for input.
# The answer: The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows the developer to test and validate initial ideas before fully committing to a more complex and polished implementation. Prototyping helps answer critical questions such as whether the approach is feasible, if the chosen data structures and logic patterns work as intended, and if there are simpler methods to achieve the desired outcome. By experimenting with a prototype, developers can identify high-risk areas and potential flaws early in the development process, making it easier and less costly to make adjustments before investing significant time and resources into the final product. This process transforms unknown challenges into manageable tasks, guiding the overall development journey.
# The answer: Object-oriented programming (OOP) offers several key advantages, including:
#
# 1. **Encapsulation**: OOP allows data and functions that operate on that data to be bundled together into objects. This encapsulation helps protect the integrity of the data and reduces complexity by hiding the internal workings of objects.
#
# 2. **Reusability**: Through inheritance, new classes can be created based on existing classes. This promotes code reuse, as common functionality can be shared among multiple classes, reducing duplication.
#
# 3. **Abstraction**: OOP enables the creation of abstract data types that represent complex real-world entities. This allows programmers to work at a higher level of abstraction, focusing on the interactions between objects rather than their internal details.
#
# 4. **Modularity**: Programs can be divided into smaller, manageable pieces (classes and objects), making it easier to develop, test, and maintain complex systems.
#
# 5. **Polymorphism**: OOP supports polymorphism, allowing methods to do different things based on the object that it is acting upon. This enhances flexibility and the ability to extend systems without modifying existing code.
#
# Overall, these advantages lead to more organized, scalable, and maintainable code, facilitating the development of robust software systems.
# ================================= Tool Message =================================
# Name: query_lesson
#
# {"messages": "Question: What is the main difference between a while and a do...while statement? Answer: The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked:\n\n- **While Loop**: The condition is checked at the beginning of the loop. If the condition is false from the start, the loop's body may not execute at all.\n\n    Example:\n    ```cpp\n    while (condition) {\n        // loop body\n    }\n    ```\n\n- **Do...While Loop**: The loop's body is executed at least once before the condition is checked at the end. This guarantees that the code inside the loop runs at least one time, regardless of whether the condition is true or false initially.\n\n    Example:\n    ```cpp\n    do {\n        // loop body\n    } while (condition);\n    ```\n\nThis difference is important when you want to ensure that the loop's body executes at least once, such as when prompting a user for input."}
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The student identifies that a prototype program addresses high-risk problems and demonstrates feasibility, which aligns with the lesson's emphasis on validating ideas. However, the answer lacks depth regarding how prototyping transforms challenges into manageable tasks.",
#       "cited_paragraph": "The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows the developer to test and validate initial ideas before fully committing to a more complex and polished implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The student's answer comprehensively covers how testing affects various stages of the software life cycle, including requirements gathering, design, implementation, maintenance, and deployment. It shows a thorough understanding of the interconnectivity of these phases.",
#       "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) influences several key stages, including: Requirements Gathering, Design, Implementation, Maintenance, Deployment."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student articulates multiple advantages of OOP, including modularity, reusability, encapsulation, abstraction, and polymorphism. This response reflects a nuanced understanding of the concepts and their implications for programming.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several key advantages, including: Encapsulation, Reusability, Abstraction, Modularity, Polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The student's answer is correct and succinctly states that C++ programs begin execution at the 'main()' function. This shows a clear understanding of C++ program structure.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The student provides a simplistic definition and examples of variables but lacks a deeper explanation of their role within programming and data manipulation, which is essential for a complete understanding.",
#       "cited_paragraph": "A variable is a storage location in a program that holds data and has a name associated with it."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student mentions declaring variables before use and suggests best practices, reflecting a good understanding of variable declaration. However, the answer could be enhanced by discussing scope and lifetime more thoroughly.",
#       "cited_paragraph": "In a C++ program, variables can be declared anywhere within the scope of a function or block."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student accurately describes the difference in condition checking between while and do...while loops, demonstrating a strong grasp of control flow concepts. The explanation is clear and includes relevant code examples.",
#       "cited_paragraph": "The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "B",
#       "reason": "The student identifies that a prototype program addresses high-risk problems and demonstrates feasibility, which aligns with the lesson's emphasis on validating ideas. However, the answer lacks depth regarding how prototyping transforms challenges into manageable tasks.",
#       "cited_paragraph": "The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows the developer to test and validate initial ideas before fully committing to a more complex and polished implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The student's answer comprehensively covers how testing affects various stages of the software life cycle, including requirements gathering, design, implementation, maintenance, and deployment. It shows a thorough understanding of the interconnectivity of these phases.",
#       "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) influences several key stages, including: Requirements Gathering, Design, Implementation, Maintenance, Deployment."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student articulates multiple advantages of OOP, including modularity, reusability, encapsulation, abstraction, and polymorphism. This response reflects a nuanced understanding of the concepts and their implications for programming.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several key advantages, including: Encapsulation, Reusability, Abstraction, Modularity, Polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The student's answer is correct and succinctly states that C++ programs begin execution at the 'main()' function. This shows a clear understanding of C++ program structure.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "C",
#       "reason": "The student provides a simplistic definition and examples of variables but lacks a deeper explanation of their role within programming and data manipulation, which is essential for a complete understanding.",
#       "cited_paragraph": "A variable is a storage location in a program that holds data and has a name associated with it."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student mentions declaring variables before use and suggests best practices, reflecting a good understanding of variable declaration. However, the answer could be enhanced by discussing scope and lifetime more thoroughly.",
#       "cited_paragraph": "In a C++ program, variables can be declared anywhere within the scope of a function or block."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student accurately describes the difference in condition checking between while and do...while loops, demonstrating a strong grasp of control flow concepts. The explanation is clear and includes relevant code examples.",
#       "cited_paragraph": "The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_Hi0unIMhSvofwG0rsMDYayoU)
#  Call ID: call_Hi0unIMhSvofwG0rsMDYayoU
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_Tp7qtbcinw2eVq2etlUcpXzL)
#  Call ID: call_Tp7qtbcinw2eVq2etlUcpXzL
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_UNfkNGM7RtRLaMKD18hY38v1)
#  Call ID: call_UNfkNGM7RtRLaMKD18hY38v1
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_bruIUXZO5OqXHNVn7v8rAVTD)
#  Call ID: call_bruIUXZO5OqXHNVn7v8rAVTD
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_IzDXHwvBsOYnjcKwke8MHF6l)
#  Call ID: call_IzDXHwvBsOYnjcKwke8MHF6l
#   Args:
#     question: What is a variable?
#   query_lesson (call_y0GYwshlOTj6YXLJpELo6wHx)
#  Call ID: call_y0GYwshlOTj6YXLJpELo6wHx
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_y6VYQGi6sLPaVqAwBWHvYJiQ)
#  Call ID: call_y6VYQGi6sLPaVqAwBWHvYJiQ
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `int main()` function. This is the starting point for all C++ code, and the program carries out the statements inside `main()` in order.
# The answer: In a C++ program, variables are typically declared within the scope of a function or block where they will be used. While modern C++ allows for variables to be declared anywhere, a good practice—especially for beginners—is to declare them near the start of the function or block. This approach improves code readability and maintenance, making it clear what role each variable plays in the program.
# The answer: A variable is a named storage location in a program that holds a value, allowing you to store and manipulate data. In C++, variables can represent different types of data, such as integers, floating-point numbers, or strings. For example, you might declare an integer variable to keep track of the number of items a traveler carries, like this: `int itemCount = 0;`. Choosing meaningful names for variables helps make your code more readable and maintainable.
# The answer: The main difference between a while and a do...while statement is in when the condition is checked.
#
# - A **while loop** checks its condition at the beginning of the loop. If the condition is false initially, the loop's body will not execute at all.
#
# - A **do...while loop**, on the other hand, checks its condition at the end of the loop. This guarantees that the loop's body will execute at least once, regardless of the condition being true or false.
#
# In summary, use a while loop when you want to check the condition before executing the loop, and use a do...while loop when you need to ensure the loop runs at least once before checking the condition.
# The answer: A prototype program plays a crucial role in problem solving by allowing developers to quickly create a preliminary version of their software to test concepts and functionalities before fully implementing them. It serves several key purposes:
#
# 1. **Exploration of Ideas**: Prototypes help in exploring different approaches to solving a problem, allowing programmers to experiment with various designs and features without committing to a complete solution.
#
# 2. **Testing Functionality**: They enable testing of specific functionalities in a controlled environment, helping to identify potential flaws or areas for improvement early in the development process.
#
# 3. **Refinement**: Prototypes facilitate iterative refinement, where developers can gather feedback, make adjustments, and enhance the design based on real usage and testing.
#
# 4. **Communication**: They serve as a communication tool among team members and stakeholders, providing a tangible representation of ideas that can be discussed and evaluated.
#
# 5. **Risk Mitigation**: By identifying issues in the early stages, prototypes help mitigate risks associated with software development, ensuring that the final product is more robust and aligned with user needs.
#
# In summary, prototype programs are essential for validating ideas, refining solutions, and ensuring that the development process is efficient and effective.
# The answer: The testing stage in the software development life cycle (SDLC) influences several key stages, including:
#
# 1. **Requirements Gathering**: Testing can help clarify requirements by identifying inconsistencies or ambiguities, leading to more accurate specifications.
#
# 2. **Design**: Insights gained during testing can influence the design phase, as issues may arise that require modifications to the architecture or design patterns used.
#
# 3. **Implementation**: During coding, testers may provide feedback that can affect how features are implemented, ensuring that code adheres to the requirements and design specifications.
#
# 4. **Maintenance**: The testing phase often uncovers bugs or issues that need fixing, which directly impacts the maintenance stage. Additionally, testing can inform future updates or enhancements based on user feedback.
#
# 5. **Deployment**: Testing results may determine whether the software is ready for deployment, influencing the decision to release the product or to delay it until identified issues are resolved.
#
# In summary, the testing stage provides critical feedback that can reshape requirements, design, implementation, and maintenance throughout the SDLC.
# The answer: Object-oriented programming (OOP) offers several key advantages:
#
# 1. **Encapsulation**: OOP allows data and functions that operate on that data to be bundled together into objects. This helps in hiding the internal state of the object from the outside world and only exposing necessary parts, leading to better data protection and reduced complexity.
#
# 2. **Reusability**: Classes can be reused across different programs. Once a class is defined, it can be instantiated multiple times, and existing classes can be extended through inheritance, allowing for greater code reuse.
#
# 3. **Inheritance**: OOP enables the creation of new classes based on existing ones. This allows for hierarchical relationships between classes and promotes code reuse, as new classes can inherit attributes and methods from parent classes.
#
# 4. **Polymorphism**: This feature allows methods to do different things based on the object it is acting upon, even if they share the same name. This provides flexibility and can simplify code by allowing the same interface to be used for different underlying data types.
#
# 5. **Modularity**: OOP promotes a modular approach to programming. By breaking down complex problems into smaller, manageable pieces (classes and objects), it becomes easier to develop, test, and maintain code.
#
# 6. **Improved Maintainability**: With organized code structures and the ability to encapsulate functionality, OOP makes it easier to maintain and update code. Changes can be made with minimal impact on other parts of the program.
#
# These advantages contribute to more structured, maintainable, and scalable code, making OOP a widely adopted programming paradigm.
# ================================= Tool Message =================================
# Name: query_lesson
#
# {"messages": "Question: What is the main difference between a while and a do...while statement? Answer: The main difference between a while and a do...while statement is in when the condition is checked. \n\n- A **while loop** checks its condition at the beginning of the loop. If the condition is false initially, the loop's body will not execute at all.\n\n- A **do...while loop**, on the other hand, checks its condition at the end of the loop. This guarantees that the loop's body will execute at least once, regardless of the condition being true or false.\n\nIn summary, use a while loop when you want to check the condition before executing the loop, and use a do...while loop when you need to ensure the loop runs at least once before checking the condition."}
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "C",
#       "reason": "The student mentions simulating behavior but misses key aspects like exploration of ideas, testing functionalities, and communication, which are vital for understanding the role of prototypes in problem-solving.",
#       "cited_paragraph": "A prototype program plays a crucial role in problem solving by allowing developers to quickly create a preliminary version of their software to test concepts and functionalities before fully implementing them."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "C",
#       "reason": "The response identifies stages but only mentions 'Refining and Coding' without elaborating on how testing influences other stages like requirements, design, maintenance, and deployment, leading to a partial understanding.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) influences several key stages, including Requirements Gathering, Design, Implementation, Maintenance, and Deployment."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "B",
#       "reason": "The answer correctly identifies reusability and ease of maintenance but lacks a discussion on other key advantages like encapsulation, inheritance, and polymorphism, indicating a mostly good understanding with minor gaps.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several key advantages: Encapsulation, Reusability, Inheritance, Polymorphism, Modularity, Improved Maintainability."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer accurately identifies that C++ programs begin execution at 'int main()' and explains its significance clearly, demonstrating a thorough understanding.",
#       "cited_paragraph": "C++ programs begin to execute at the `int main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The definition given is mostly correct but could be improved by emphasizing that a variable not only holds a specific type of data but also has a defined scope, indicating a good understanding with minor gaps.",
#       "cited_paragraph": "A variable is a named storage location in a program that holds a value, allowing you to store and manipulate data."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The explanation correctly identifies global and local declarations but lacks depth on best practices or implications of declaration locations, indicating a good understanding with minor gaps.",
#       "cited_paragraph": "In a C++ program, variables are typically declared within the scope of a function or block where they will be used."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student provides a clear and accurate distinction between the two types of loops, explaining the conditions effectively, demonstrating a thorough understanding.",
#       "cited_paragraph": "The main difference between a while and a do...while statement is in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "C",
#       "reason": "The student mentions simulating behavior but misses key aspects like exploration of ideas, testing functionalities, and communication, which are vital for understanding the role of prototypes in problem-solving.",
#       "cited_paragraph": "A prototype program plays a crucial role in problem solving by allowing developers to quickly create a preliminary version of their software to test concepts and functionalities before fully implementing them."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "C",
#       "reason": "The response identifies stages but only mentions 'Refining and Coding' without elaborating on how testing influences other stages like requirements, design, maintenance, and deployment, leading to a partial understanding.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) influences several key stages, including Requirements Gathering, Design, Implementation, Maintenance, and Deployment."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "B",
#       "reason": "The answer correctly identifies reusability and ease of maintenance but lacks a discussion on other key advantages like encapsulation, inheritance, and polymorphism, indicating a mostly good understanding with minor gaps.",
#       "cited_paragraph": "Object-oriented programming (OOP) offers several key advantages: Encapsulation, Reusability, Inheritance, Polymorphism, Modularity, Improved Maintainability."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer accurately identifies that C++ programs begin execution at 'int main()' and explains its significance clearly, demonstrating a thorough understanding.",
#       "cited_paragraph": "C++ programs begin to execute at the `int main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "B",
#       "reason": "The definition given is mostly correct but could be improved by emphasizing that a variable not only holds a specific type of data but also has a defined scope, indicating a good understanding with minor gaps.",
#       "cited_paragraph": "A variable is a named storage location in a program that holds a value, allowing you to store and manipulate data."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The explanation correctly identifies global and local declarations but lacks depth on best practices or implications of declaration locations, indicating a good understanding with minor gaps.",
#       "cited_paragraph": "In a C++ program, variables are typically declared within the scope of a function or block where they will be used."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student provides a clear and accurate distinction between the two types of loops, explaining the conditions effectively, demonstrating a thorough understanding.",
#       "cited_paragraph": "The main difference between a while and a do...while statement is in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_cy2DATR0PsLUjGzeD0w541FG)
#  Call ID: call_cy2DATR0PsLUjGzeD0w541FG
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_MM2uQshTcnSwlAQPgNbpTMg6)
#  Call ID: call_MM2uQshTcnSwlAQPgNbpTMg6
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_yOVLwNeBIOJUf87fKKXgMGgs)
#  Call ID: call_yOVLwNeBIOJUf87fKKXgMGgs
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_sXOSeWdJ3rfenuvEvjec8Ew2)
#  Call ID: call_sXOSeWdJ3rfenuvEvjec8Ew2
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_kOQ2ZVb8Nqzx6xkq6YS7Cf0M)
#  Call ID: call_kOQ2ZVb8Nqzx6xkq6YS7Cf0M
#   Args:
#     question: What is a variable?
#   query_lesson (call_xmIcFTKRoGAY1Cw7ieTOaOqM)
#  Call ID: call_xmIcFTKRoGAY1Cw7ieTOaOqM
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_TVTA1wOf1a9cyTvJMfZRRUQV)
#  Call ID: call_TVTA1wOf1a9cyTvJMfZRRUQV
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `main()` function. This is the starting point of every C++ program, where the execution of code begins.
# The answer: In a C++ program, variables can be declared anywhere, but it is a good practice—especially for beginners—to declare them near the start of the function or block where they will be used. This approach makes it clearer what role each variable plays and helps keep the code organized and easier to read.
# The answer: A variable in programming is a storage location identified by a name that holds data which can be changed during the execution of a program. Variables allow you to store information, such as numbers or text, so that you can manipulate and use that data throughout your code. For example, in C++, an integer variable can be declared as `int itemCount = 0;` to keep track of the number of items, while a string variable can be declared as `std::string itemName = "Healing Potion";` to store the name of an item. Choosing meaningful names for variables makes your code easier to read and maintain.
# The answer: The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked.
#
# - In a **while loop**, the condition is evaluated at the beginning of the loop. If the condition is false initially, the loop body may not execute at all.
#
#   Example:
#   ```cpp
#   while (condition) {
#       // Loop body
#   }
#   ```
#
# - In a **do...while loop**, the loop body is executed at least once before the condition is checked. This guarantees that the code within the loop will run at least one time, even if the condition is false initially.
#
#   Example:
#   ```cpp
#   do {
#       // Loop body
#   } while (condition);
#   ```
#
# This distinction is important for scenarios where you want to ensure that the loop's body runs at least once, such as prompting a user for input.
# The answer: A prototype program plays a crucial role in problem-solving by allowing developers to create a preliminary version of a software application to test and refine ideas before full implementation. Prototypes help in:
#
# 1. **Visualization**: They provide a tangible representation of concepts, allowing developers and stakeholders to see how the final product might function.
# 2. **Testing Ideas**: Prototypes enable experimentation with different features and functionalities, helping to identify what works and what doesn’t early in the development process.
# 3. **Feedback**: They facilitate gathering feedback from users and stakeholders, which can inform necessary adjustments and improvements.
# 4. **Refinement**: Prototypes allow for iterative development, meaning features can be tested, refined, and improved based on real usage and testing outcomes.
#
# Overall, using prototypes helps ensure that the final product aligns closely with user needs and expectations, while also reducing the risk of costly errors during full-scale development.
# The answer: The testing stage in the Software Development Life Cycle (SDLC) influences several key stages:
#
# 1. **Requirements Gathering**: Testing helps ensure that the requirements are clear and complete. If issues are discovered during testing, it may lead to a reevaluation of the requirements.
#
# 2. **Design**: Insights gained from testing can influence design decisions. For instance, if certain functionalities are difficult to test, the design might need to be adjusted to improve testability.
#
# 3. **Implementation**: During coding, developers may adopt certain practices or patterns that facilitate easier testing, such as writing modular code or including logging features.
#
# 4. **Deployment**: Prior to deployment, testing is critical to ensure that the software is stable and meets the quality standards required for release.
#
# 5. **Maintenance**: Testing continues to play a role during the maintenance phase. Ongoing testing helps identify bugs and issues that arise after the software is in use, guiding further updates and refinements.
#
# Overall, testing acts as a feedback mechanism that can significantly impact and improve the quality and effectiveness of each stage in the software development life cycle.
# The answer: The main advantages associated with object-oriented programming (OOP) include:
#
# 1. **Encapsulation**: OOP allows for bundling data (attributes) and methods (functions) that operate on that data into a single unit called an object. This helps in protecting the internal state of the object and only exposing necessary parts of it, leading to better data integrity.
#
# 2. **Abstraction**: OOP enables the creation of abstract data types, allowing programmers to focus on high-level operations rather than low-level implementation details. This simplifies complex systems by hiding unnecessary details, making the code easier to understand and maintain.
#
# 3. **Inheritance**: OOP supports inheritance, which allows new classes to inherit properties and behaviors from existing classes. This promotes code reuse and can lead to a hierarchical organization of classes, making it easier to manage and extend codebases.
#
# 4. **Polymorphism**: OOP provides the ability to define methods in different classes that share the same name but behave differently based on the object invoking them. This allows for flexibility and the ability to handle various data types through a unified interface.
#
# 5. **Improved Maintainability**: By organizing code into classes and objects, OOP makes it easier to modify and extend existing code. Changes can often be made in one place without affecting other parts of the system.
#
# 6. **Enhanced Collaboration**: OOP promotes a modular approach to programming, which can make it easier for teams to work on different components of a software project simultaneously, thereby enhancing collaboration and productivity.
#
# These advantages contribute to building more structured, scalable, and maintainable software applications.
# ================================= Tool Message =================================
# Name: query_lesson
#
# {"messages": "Question: What is the main difference between a while and a do...while statement? Answer: The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked. \n\n- In a **while loop**, the condition is evaluated at the beginning of the loop. If the condition is false initially, the loop body may not execute at all.\n\n  Example:\n  ```cpp\n  while (condition) {\n      // Loop body\n  }\n  ```\n\n- In a **do...while loop**, the loop body is executed at least once before the condition is checked. This guarantees that the code within the loop will run at least one time, even if the condition is false initially.\n\n  Example:\n  ```cpp\n  do {\n      // Loop body\n  } while (condition);\n  ```\n\nThis distinction is important for scenarios where you want to ensure that the loop's body runs at least once, such as prompting a user for input."}
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "A",
#       "reason": "The student's answer accurately captures the essence of a prototype program, including its role in visualization, testing ideas, gathering feedback, and refinement. This reflects a thorough understanding of both prototyping and problem-solving.",
#       "cited_paragraph": "A prototype program plays a crucial role in problem-solving by allowing developers to create a preliminary version of a software application to test and refine ideas before full implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The student correctly identifies the stages influenced by testing in the SDLC, including requirements gathering, design, implementation, deployment, and maintenance. This comprehensive understanding demonstrates a nuanced grasp of the SDLC.",
#       "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) influences several key stages."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a detailed answer that covers encapsulation, inheritance, polymorphism, and reusability. This indicates a thorough understanding of OOP concepts and their benefits.",
#       "cited_paragraph": "The main advantages associated with object-oriented programming (OOP) include: Encapsulation, Abstraction, Inheritance, Polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The student correctly identifies that C++ programs begin execution at the 'main()' function, demonstrating a clear understanding of C++ program structure.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "A",
#       "reason": "The student's answer accurately describes a variable as a storage location in memory that can hold data, with a good example. This indicates a thorough understanding of the concept of variables.",
#       "cited_paragraph": "A variable in programming is a storage location identified by a name that holds data which can be changed during the execution of a program."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "A",
#       "reason": "The student correctly states that variables can be declared anywhere but emphasizes best practices for clarity and organization, reflecting a strong understanding of C++ program structure.",
#       "cited_paragraph": "In a C++ program, variables can be declared anywhere, but it is a good practice to declare them near the start of the function or block."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student clearly articulates the main difference between while and do...while loops, including examples. This shows a thorough understanding of control flow and loops in programming.",
#       "cited_paragraph": "The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "A",
#       "reason": "The student's answer accurately captures the essence of a prototype program, including its role in visualization, testing ideas, gathering feedback, and refinement. This reflects a thorough understanding of both prototyping and problem-solving.",
#       "cited_paragraph": "A prototype program plays a crucial role in problem-solving by allowing developers to create a preliminary version of a software application to test and refine ideas before full implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The student correctly identifies the stages influenced by testing in the SDLC, including requirements gathering, design, implementation, deployment, and maintenance. This comprehensive understanding demonstrates a nuanced grasp of the SDLC.",
#       "cited_paragraph": "The testing stage in the Software Development Life Cycle (SDLC) influences several key stages."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The student provides a detailed answer that covers encapsulation, inheritance, polymorphism, and reusability. This indicates a thorough understanding of OOP concepts and their benefits.",
#       "cited_paragraph": "The main advantages associated with object-oriented programming (OOP) include: Encapsulation, Abstraction, Inheritance, Polymorphism."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The student correctly identifies that C++ programs begin execution at the 'main()' function, demonstrating a clear understanding of C++ program structure.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "A",
#       "reason": "The student's answer accurately describes a variable as a storage location in memory that can hold data, with a good example. This indicates a thorough understanding of the concept of variables.",
#       "cited_paragraph": "A variable in programming is a storage location identified by a name that holds data which can be changed during the execution of a program."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "A",
#       "reason": "The student correctly states that variables can be declared anywhere but emphasizes best practices for clarity and organization, reflecting a strong understanding of C++ program structure.",
#       "cited_paragraph": "In a C++ program, variables can be declared anywhere, but it is a good practice to declare them near the start of the function or block."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student clearly articulates the main difference between while and do...while loops, including examples. This shows a thorough understanding of control flow and loops in programming.",
#       "cited_paragraph": "The main difference between a while loop and a do...while loop in C++ lies in when the condition is checked."
#     }
#   ]
# }
# ```
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_gnGVCinLkyrAi3PWI0WpG4hF)
#  Call ID: call_gnGVCinLkyrAi3PWI0WpG4hF
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_UjMG5IqYrLy387kVVQpaVFxf)
#  Call ID: call_UjMG5IqYrLy387kVVQpaVFxf
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_uWtjkboHG0KvC4HAH0PMPjbw)
#  Call ID: call_uWtjkboHG0KvC4HAH0PMPjbw
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_PNBznjZjKmmVfqlcIDJTM91m)
#  Call ID: call_PNBznjZjKmmVfqlcIDJTM91m
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_nq79hzgQJAQXMoV1vWNdlutR)
#  Call ID: call_nq79hzgQJAQXMoV1vWNdlutR
#   Args:
#     question: What is a variable?
#   query_lesson (call_u3WQ8urEZpB1fLJvnOjDhjHK)
#  Call ID: call_u3WQ8urEZpB1fLJvnOjDhjHK
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_U7LHJI5Dto0lYQShlmp6UKcD)
#  Call ID: call_U7LHJI5Dto0lYQShlmp6UKcD
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `int main()` function. This is the starting point for every program, where the execution of code starts, regardless of the program's complexity.
# The answer: In a C++ program, variables can be declared anywhere, but a good practice—especially for beginners—is to declare them near the start of the function or block where they will be used. This early declaration helps make the code clearer and easier to read, as it specifies the role of each variable in the logic of the program.
# The answer: The role of a prototype program in problem-solving is to create a quick, rough version of the software that allows the developer to test and validate ideas before fully committing to a more complex solution. Prototyping helps identify feasibility, assess chosen data structures and logic patterns, and discover potential flaws early in the development process. By experimenting with a prototype, developers can manage risks, simplify challenges, and refine their approach, ensuring that they address issues while they are still easy and inexpensive to fix. This iterative process ultimately leads to a stronger, more reliable final product.
# ...
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "B",
#       "reason": "The student's answer correctly identifies where local and global variables are declared, but it could be improved by mentioning the importance of declaring variables at the start of their scope for clarity.",
#       "cited_paragraph": "In a C++ program, variables are typically declared at the start of the function or block where they will be used."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The student answer clearly distinguishes between while and do...while loops, explaining the key difference in condition checking effectively with examples, showing a solid understanding.",
#       "cited_paragraph": "The main difference between a while and a do...while statement is when the condition is checked."
#     }
#   ]
# }
# ================================== Ai Message ==================================
# Tool Calls:
#   query_lesson (call_E8cGFbTzRPy4XffqqOYfHQfv)
#  Call ID: call_E8cGFbTzRPy4XffqqOYfHQfv
#   Args:
#     question: What is the role of a prototype program in problem solving?
#   query_lesson (call_1nsRm6cVLO9vur2LoW3VbwxC)
#  Call ID: call_1nsRm6cVLO9vur2LoW3VbwxC
#   Args:
#     question: What stages in the software life cycle are influenced by the testing stage?
#   query_lesson (call_EzWf9GTJza7Ci9CoHioQG3JC)
#  Call ID: call_EzWf9GTJza7Ci9CoHioQG3JC
#   Args:
#     question: What are the main advantages associated with object-oriented programming?
#   query_lesson (call_ozEq52YpEAQYL73uR5VXUl5R)
#  Call ID: call_ozEq52YpEAQYL73uR5VXUl5R
#   Args:
#     question: Where do C++ programs begin to execute?
#   query_lesson (call_EObyDSaFHoIxkMtNa34HtgmT)
#  Call ID: call_EObyDSaFHoIxkMtNa34HtgmT
#   Args:
#     question: What is a variable?
#   query_lesson (call_omLfcveRh6Gybu4NSM5mKE2l)
#  Call ID: call_omLfcveRh6Gybu4NSM5mKE2l
#   Args:
#     question: Where are variables declared in a C++ program?
#   query_lesson (call_c9ENJhmdk4Fif1sVVFgS6Gzx)
#  Call ID: call_c9ENJhmdk4Fif1sVVFgS6Gzx
#   Args:
#     question: What is the main difference between a while and a do...while statement?
# The answer: C++ programs begin to execute at the `main()` function. This is the starting point of the program, where execution commences, regardless of the complexity of the code or the number of files and classes involved.
# The answer: A variable is a named storage location in a program that holds data. It allows developers to store, modify, and retrieve information during the execution of a program. In C++, a variable must be declared with a specific type (such as integer, floating-point, or string), which determines what kind of data it can hold. For example, an integer variable might be used to count items, while a string variable could store the name of an item. Choosing meaningful names for variables helps make the code clearer and easier to maintain.
# The answer: The main difference between a while and a do...while statement in C++ is when the condition is checked to control the repetition of the loop:
#
# - **while loop**: The condition is checked at the beginning of the loop. If the condition is false initially, the code inside the loop will not execute at all.
#
#   Example:
#   ```cpp
#   while (condition) {
#       // code to execute
#   }
#   ```
#
# - **do...while loop**: The code inside the loop is executed at least once before the condition is checked at the end of the loop. This guarantees that the loop will run at least one time, regardless of whether the condition is true or false initially.
#
#   Example:
#   ```cpp
#   do {
#       // code to execute
#   } while (condition);
#   ```
#
# In summary, the **while loop** checks the condition before executing the loop body, while the **do...while loop** checks the condition after executing the loop body.
# The answer: In a C++ program, variables are typically declared near the start of the function or block where they will be used. This practice helps maintain clarity about the role of each variable, making the code easier to read and maintain. For instance, in the main() function, you would declare variables like this:
#
# ```cpp
# int main() {
#     int itemCount = 0; // Start with an empty inventory
#     std::string itemName = "Healing Potion";
#     // Other code follows...
# }
# ```
#
# Declaring variables early allows you to organize your code effectively as it grows in complexity.
# The answer: The testing stage in the software development life cycle (SDLC) influences several key stages, including:
#
# 1. **Requirements Analysis**: Testing helps to verify that the requirements are correctly understood and implemented. If issues are found during testing, it may require revisiting and refining the requirements.
#
# 2. **Design**: Testing feedback can inform the design stage, leading to adjustments in architecture or design choices to better meet the requirements or improve usability.
#
# 3. **Implementation**: During the coding phase, testing can guide developers to write better code by highlighting areas that need more focus, such as edge cases or potential bugs.
#
# 4. **Deployment**: Before deployment, testing ensures that the software is stable and meets quality standards, influencing the readiness for release.
#
# 5. **Maintenance**: After deployment, ongoing testing (such as regression testing) influences how the software is maintained, guiding updates, bug fixes, and enhancements based on user feedback and performance.
#
# Overall, the testing stage is integral to ensuring quality and functionality throughout the entire software life cycle.
# The answer: The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows developers, like Alden, to test initial ideas and concepts before committing to a full-scale implementation. Prototyping helps answer critical early questions about feasibility, the effectiveness of chosen data structures, and logic patterns. By experimenting with a prototype, developers can identify potential flaws or high-risk areas early in the process, making it easier and more cost-effective to address issues before investing significant time and resources into a polished product. Essentially, prototyping transforms unknown challenges into manageable tasks, guiding the development process more effectively.
# The answer: The main advantages of object-oriented programming (OOP) include:
#
# 1. **Encapsulation**: OOP allows you to bundle data (attributes) and methods (functions) that operate on that data into a single unit called an object. This helps in hiding the internal state of the object and only exposes what is necessary, promoting a modular approach.
#
# 2. **Reusability**: OOP encourages code reusability through inheritance, where a new class can inherit properties and behavior from an existing class. This reduces redundancy and makes it easier to maintain and extend code.
#
# 3. **Abstraction**: OOP allows you to define complex systems in simpler terms by using abstract classes and interfaces. This means you can work at a higher level of complexity without needing to understand all the underlying details.
#
# 4. **Polymorphism**: OOP supports polymorphism, which allows methods to do different things based on the object that it is acting on. This flexibility enables the same interface to be used for different underlying forms (data types).
#
# 5. **Improved Maintenance**: Because OOP promotes a modular structure, it simplifies debugging and updating code. Changes made to one part of the program are less likely to affect other parts.
#
# 6. **Real-world Modeling**: OOP allows for modeling real-world entities more intuitively, making it easier to represent complex systems and relationships in a way that is more understandable.
#
# These advantages make OOP a powerful paradigm for designing and maintaining software systems, especially as they grow in size and complexity.
# ================================= Tool Message =================================
# Name: query_lesson
#
# {"messages": "Question: What is the main difference between a while and a do...while statement? Answer: The main difference between a while and a do...while statement in C++ is when the condition is checked to control the repetition of the loop:\n\n- **while loop**: The condition is checked at the beginning of the loop. If the condition is false initially, the code inside the loop will not execute at all.\n\n  Example:\n  ```cpp\n  while (condition) {\n      // code to execute\n  }\n  ```\n\n- **do...while loop**: The code inside the loop is executed at least once before the condition is checked at the end of the loop. This guarantees that the loop will run at least one time, regardless of whether the condition is true or false initially.\n\n  Example:\n  ```cpp\n  do {\n      // code to execute\n  } while (condition);\n  ```\n\nIn summary, the **while loop** checks the condition before executing the loop body, while the **do...while loop** checks the condition after executing the loop body."}
# ================================== Ai Message ==================================
#
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "A",
#       "reason": "The response demonstrates a thorough understanding of the role of prototype programs, explaining their function in testing ideas, identifying flaws, and guiding development effectively.",
#       "cited_paragraph": "The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows developers, like Alden, to test initial ideas and concepts before committing to a full-scale implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The answer provides a comprehensive overview of how the testing stage affects various stages of the software development life cycle, including requirements analysis, design, implementation, deployment, and maintenance.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) influences several key stages, including Requirements Analysis, Design, Implementation, Deployment, and Maintenance."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The answer covers all major advantages of object-oriented programming, including encapsulation, reusability, abstraction, polymorphism, improved maintenance, and real-world modeling, demonstrating a nuanced understanding.",
#       "cited_paragraph": "The main advantages of object-oriented programming (OOP) include Encapsulation, Reusability, Abstraction, Polymorphism, Improved Maintenance, and Real-world Modeling."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer correctly identifies that C++ programs begin execution at the `main()` function, meeting the criteria for a complete understanding.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "A",
#       "reason": "The response provides a clear definition of a variable, explaining its purpose, how it holds data, and the importance of declaration in C++, which indicates a thorough understanding.",
#       "cited_paragraph": "A variable is a named storage location in a program that holds data."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "A",
#       "reason": "The answer accurately describes where variables are typically declared in C++, providing clear examples and emphasizing clarity and organization in code, showing excellent comprehension.",
#       "cited_paragraph": "In a C++ program, variables are typically declared near the start of the function or block where they will be used."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The answer effectively explains the key difference between while and do...while loops, including examples, demonstrating a solid understanding of control flow in programming.",
#       "cited_paragraph": "The main difference between a while and a do...while statement in C++ is when the condition is checked to control the repetition of the loop."
#     }
#   ]
# }
# ================================== Ai Message ==================================
#
# {
#   "evaluated_questions": [
#     {
#       "question": "What is the role of a prototype program in problem solving?",
#       "score": "A",
#       "reason": "The response demonstrates a thorough understanding of the role of prototype programs, explaining their function in testing ideas, identifying flaws, and guiding development effectively.",
#       "cited_paragraph": "The role of a prototype program in problem solving is to create a quick, rough version of a software solution that allows developers, like Alden, to test initial ideas and concepts before committing to a full-scale implementation."
#     },
#     {
#       "question": "What stages in the software life cycle are influenced by the testing stage?",
#       "score": "A",
#       "reason": "The answer provides a comprehensive overview of how the testing stage affects various stages of the software development life cycle, including requirements analysis, design, implementation, deployment, and maintenance.",
#       "cited_paragraph": "The testing stage in the software development life cycle (SDLC) influences several key stages, including Requirements Analysis, Design, Implementation, Deployment, and Maintenance."
#     },
#     {
#       "question": "What are the main advantages associated with object-oriented programming?",
#       "score": "A",
#       "reason": "The answer covers all major advantages of object-oriented programming, including encapsulation, reusability, abstraction, polymorphism, improved maintenance, and real-world modeling, demonstrating a nuanced understanding.",
#       "cited_paragraph": "The main advantages of object-oriented programming (OOP) include Encapsulation, Reusability, Abstraction, Polymorphism, Improved Maintenance, and Real-world Modeling."
#     },
#     {
#       "question": "Where do C++ programs begin to execute?",
#       "score": "A",
#       "reason": "The answer correctly identifies that C++ programs begin execution at the `main()` function, meeting the criteria for a complete understanding.",
#       "cited_paragraph": "C++ programs begin to execute at the `main()` function."
#     },
#     {
#       "question": "What is a variable?",
#       "score": "A",
#       "reason": "The response provides a clear definition of a variable, explaining its purpose, how it holds data, and the importance of declaration in C++, which indicates a thorough understanding.",
#       "cited_paragraph": "A variable is a named storage location in a program that holds data."
#     },
#     {
#       "question": "Where are variables declared in a C++ program?",
#       "score": "A",
#       "reason": "The answer accurately describes where variables are typically declared in C++, providing clear examples and emphasizing clarity and organization in code, showing excellent comprehension.",
#       "cited_paragraph": "In a C++ program, variables are typically declared near the start of the function or block where they will be used."
#     },
#     {
#       "question": "What is the main difference between a while and a do...while statement?",
#       "score": "A",
#       "reason": "The answer effectively explains the key difference between while and do...while loops, including examples, demonstrating a solid understanding of control flow in programming.",
#       "cited_paragraph": "The main difference between a while and a do...while statement in C++ is when the condition is checked to control the repetition of the loop."
#     }
#   ]
# }

# %% [markdown]
# #### Evaluate

# %%
import pandas as pd
def format_dict_to_dataframe(questions_dict, type='output'):
    dfs_list = []
    records = []
    for student_id in questions_dict.keys():    
        to_iterate = questions_dict[student_id]['evaluated_questions'] if type == 'output' else questions_dict[student_id]
        
        for question in to_iterate:
            record = question.copy()
            record['student_id'] = student_id
            records.append(record)

    grade_mapping = {
        'A': 5.0, 'B': 4.0, 'C': 3.0, 'D': 2.0, 'E': 1.0,'F': 0.0
    }

    formated_df = pd.DataFrame(records)
    y_col_name = 'y_pred' if type=='output' else 'y_true'
    formated_df[y_col_name] = formated_df['score'].map(grade_mapping) if type == 'output' else formated_df['ground_truth_score']
    return formated_df
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import numpy as np
from sklearn.metrics import (
    mean_absolute_error, 
    mean_absolute_percentage_error, 
    mean_squared_error, 
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix
)

def print_error_metrics(df, pred_col='y_pred', true_col='y_true'):
    """
    Prints out error metrics for regression and classification performance
    based on predicted and true values.
    """
    y_pred = df[pred_col]
    y_true = df[true_col]
    
    # Regression Metrics
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    print("Regression Metrics:")
    print(f"  MAE  (Mean Absolute Error): {mae:.2f}")
    print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    
    # Classification Metrics
    print("\nClassification Metrics:")
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    conf_matrix = confusion_matrix(y_true, y_pred)
    
    print(f"  Accuracy: {accuracy:.2%}")
    print(f"  Precision (Weighted): {precision:.2%}")
    print(f"  Recall (Weighted): {recall:.2%}")
    print(f"  F1 Score (Weighted): {f1:.2%}")
    print("\nConfusion Matrix:")
    print(pd.DataFrame(conf_matrix, index=[f"True {i}" for i in range(conf_matrix.shape[0])], 
                                      columns=[f"Pred {i}" for i in range(conf_matrix.shape[1])]))


def plot_error_distributions(df, pred_col='y_pred', true_col='y_true'):
    """
    Creates plots to visualize the distribution of errors.
    - A histogram of the absolute errors to see how they cluster.
    - A boxplot of the errors to show spread and outliers.
    """
    y_pred = df[pred_col]
    y_true = df[true_col]
    errors = y_pred - y_true
    absolute_errors = errors.abs()
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    
    # Histogram of absolute errors
    sns.histplot(absolute_errors, kde=True, ax=axes[0], bins=10)
    axes[0].set_title("Absolute Error Distribution")
    axes[0].set_xlabel("Absolute Error")
    axes[0].set_ylabel("Frequency")
    
    # Boxplot of absolute errors
    sns.boxplot(x=absolute_errors, ax=axes[1])
    axes[1].set_title("Absolute Error Boxplot")
    axes[1].set_xlabel("Absolute Error")
    
    plt.tight_layout()
    plt.show()

# %%
ground_truth_data = load_json_file('data/evals/open_questions_lesson_1_ground_truth.json')

gpt_4o_one_shot = load_json_file('gpt_4o_one_shot_final_responses.json')
one_shot_mini = load_json_file('one_shot_final_responses.json')
one_shot_reflection = load_json_file('one_shot_reflection_final_responses.json')
basic_rag_mini = load_json_file('graph_rag_final_responses.json')

for model_data in [gpt_4o_one_shot, one_shot_mini, one_shot_reflection, basic_rag_mini]:
    df_preds = format_dict_to_dataframe(model_data, 'output')
    df_true = format_dict_to_dataframe(ground_truth_data, type='gt')

    merged_df = df_preds.merge(df_true, on=['student_id','question'], how='left').fillna(0.0)
    print_error_metrics(merged_df, pred_col='y_pred', true_col='y_true')
# Out:
# Regression Metrics:
#   MAE  (Mean Absolute Error): 0.84
#   RMSE (Root Mean Squared Error): 1.33
#
# Classification Metrics:
#   Accuracy: 45.81%
#   Precision (Weighted): 55.08%
#   Recall (Weighted): 45.81%
#   F1 Score (Weighted): 47.73%
#
# Confusion Matrix:
#         Pred 0  Pred 1  Pred 2  Pred 3  Pred 4  Pred 5
# True 0       2       0       1       0       0       0
# True 1       1       0       0       3       2       0
# True 2       1       0       0       6       9       5
# True 3       2       0       1       6      13       3
# True 4       0       0       0      10      16       4
# True 5       4       0       0      10      35      69
# Regression Metrics:
#   MAE  (Mean Absolute Error): 0.87
#   RMSE (Root Mean Squared Error): 1.35
#
# Classification Metrics:
#   Accuracy: 46.31%
#   Precision (Weighted): 57.56%
#   Recall (Weighted): 46.31%
#   F1 Score (Weighted): 47.62%
#
# Confusion Matrix:
#         Pred 0  Pred 1  Pred 2  Pred 3  Pred 4  Pred 5
# True 0       1       0       1       1       0       0
# True 1       1       0       0       0       5       0
# True 2       1       0       0       3      14       3
# True 3       2       0       1       7      12       3
# True 4       0       0       0       3      23       4
# True 5       3       0       2      10      40      63
# Regression Metrics:
#   MAE  (Mean Absolute Error): 0.82
#   RMSE (Root Mean Squared Error): 1.25
#
# Classification Metrics:
#   Accuracy: 46.31%
#   Precision (Weighted): 52.60%
#   Recall (Weighted): 46.31%
#   F1 Score (Weighted): 46.70%
#
# Confusion Matrix:
#         Pred 0  Pred 1  Pred 2  Pred 3  Pred 4  Pred 5
# True 0       1       0       1       1       0       0
# True 1       0       0       0       1       3       2
# True 2       0       0       0       6       9       6
# True 3       0       0       2       5      12       6
# True 4       0       0       0       4      21       5
# True 5       0       0       1      13      37      67
# Regression Metrics:
#   MAE  (Mean Absolute Error): 0.86
#   RMSE (Root Mean Squared Error): 1.34
#
# Classification Metrics:
#   Accuracy: 47.57%
#   Precision (Weighted): 46.93%
#   Recall (Weighted): 47.57%
#   F1 Score (Weighted): 45.93%
#
# Confusion Matrix:
#         Pred 0  Pred 1  Pred 2  Pred 3  Pred 4  Pred 5
# True 0       0       0       2       1       3       0
# True 1       0       0       0       0       5       1
# True 2       0       0       0       3      11       7
# True 3       0       0       1       3      11      10
# True 4       0       0       0       1      16      13
# True 5       0       0       2       5      32      79
